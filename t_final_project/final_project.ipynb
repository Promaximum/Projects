# %% [markdown]
# # **Телеком**
#
# Оператор связи «ТелеДом» хочет бороться с оттоком клиентов. Для этого его сотрудники начнут предлагать промокоды и специальные условия всем, кто планирует отказаться от услуг связи. Чтобы заранее находить таких пользователей, «ТелеДому» нужна модель, которая будет предсказывать, разорвёт ли абонент договор. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и услугах. Задача — обучить на этих данных модель для прогноза оттока клиентов.
#
# #### **Описание услуг**
#
# Оператор предоставляет два основных типа услуг:
# 1. Стационарную телефонную связь. Телефон можно подключить к нескольким линиям одновременно.
# 2. Интернет. Подключение бывает двух типов: через телефонную линию DSL (англ. digital subscriber line — «цифровая абонентская линия») или оптоволоконный кабель (англ. fiber optic).
#
# Также абонентам доступен ряд услуг:
# * Интернет-безопасность: антивирус (Device Protection) и блокировка опасных сайтов (Online Security);
# * Выделенная линия технической поддержки (Tech Support);
# * Облачное хранилище файлов для резервного копирования данных (Online Backup);
# * Стриминговое телевидение (Streaming TV) и каталог фильмов (Streaming Movies).
#
# За услуги клиенты могут платить ежемесячно или раз в 1–2 года. Доступны различные способы расчёта и возможность получить электронный чек.
#
# #### **Описание данных**
#
# Данные хранятся в базе данных PostgreSQL. Она состоит из нескольких таблиц:
# * `contract` — информация о договорах;
# * `personal` — персональные данные клиентов;
# * `internet` — информация об интернет-услугах;
# * `phone` — информация об услугах телефонии.
#
# **Таблица `telecom.contract`**
# * `customerID` — ID абонента;
# * `BeginDate` — дата начала действия договора;
# * `EndDate` — дата окончания действия договора;
# * `Type` — тип оплаты: раз в год-два или ежемесячно;
# * `PaperlessBilling` — электронный расчётный лист;
# * `PaymentMethod` — тип платежа;
# * `MonthlyCharges` — расходы за месяц;
# * `TotalCharges` — общие расходы абонента.
#
# **Таблица `telecom.personal`**
# * `customerID` — ID пользователя;
# * `gender` — пол;
# * `SeniorCitizen` — является ли абонент пенсионером;
# * `Partner` — есть ли у абонента супруг или супруга;
# * `Dependents` — есть ли у абонента дети.
#
# **Таблица `telecom.internet`**
# * `customerID` — ID пользователя;
# * `InternetService` — тип подключения;
# * `OnlineSecurity` — блокировка опасных сайтов;
# * `OnlineBackup` — облачное хранилище файлов для резервного копирования данных;
# * `DeviceProtection` — антивирус;
# * `TechSupport` — выделенная линия технической поддержки;
# * `StreamingTV` — стриминговое телевидение;
# * `StreamingMovies` — каталог фильмов.
#
# **Таблица `telecom.phone`**
# * `customerID` — ID пользователя;
# * `MultipleLines` — подключение телефона к нескольким линиям одновременно.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# # Шаг 1. Загрузка данных

# %%
# !pip install catboost psycopg2 optuna
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.10/dist-packages (2.9.9)
# Collecting optuna
#   Downloading optuna-3.4.0-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 45.6 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.12.1-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 26.0 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna, catboost
# Successfully installed Mako-1.2.4 alembic-1.12.1 catboost-1.2.2 colorlog-6.7.0 optuna-3.4.0

# %%
import pandas as pd
import numpy as np
import psycopg2 #без этой библиотеки не работал код в colab
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
from sqlalchemy import create_engine
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import make_scorer, roc_auc_score, roc_curve, accuracy_score, precision_score, recall_score, precision_recall_curve, confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import  Conv2D, Flatten, AvgPool2D, Dense, GlobalAveragePooling2D, BatchNormalization
import tensorflow as tf

from tqdm import notebook
from tqdm.auto import tqdm

RANDOM_STATE = 1022020

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

# %%
db_config = {
    'user': 'praktikum_student',
    'password': 'Sdf4$2;d-d30pp',
    'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
    'port': 6432,
    'database': 'data-science-final'
}

# %%
connection = psycopg2.connect(**db_config) #установим соединение с базой данных PostgreSQL с использованием библиотеки psycopg2

# %%
query = 'SELECT * FROM telecom.contract;'

sample_telecom_contract = pd.read_sql_query(query, connection)
sample_telecom_contract.head(10)
# Out:
# <ipython-input-6-0c5fb9d0e3b4>:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sample_telecom_contract = pd.read_sql_query(query, connection)
#    customerID   BeginDate     EndDate            Type PaperlessBilling  \
# 0  4472-LVYGI  2020-02-01        None        Two year              Yes
# 1  3115-CZMZD  2020-02-01        None        Two year               No
# 2  3668-QPYBK  2018-08-09  2019-12-01  Month-to-month              Yes
# 3  5709-LVOEQ  2020-02-01        None        Two year               No
# 4  9237-HQITU  2019-01-26  2019-11-01  Month-to-month              Yes
# 5  9305-CDSKC  2018-12-26  2019-11-01  Month-to-month              Yes
# 6  4367-NUYAO  2020-02-01        None        Two year               No
# 7  1371-DWPAZ  2020-02-01        None        Two year               No
# 8  7892-POOKP  2019-04-27  2019-11-01  Month-to-month              Yes
# 9  3213-VVOLG  2020-02-01        None        Two year               No
#
#                PaymentMethod  MonthlyCharges  TotalCharges
# 0  Bank transfer (automatic)           52.55           NaN
# 1               Mailed check           20.25           NaN
# 2               Mailed check           53.85        108.15
# 3               Mailed check           80.85           NaN
# 4           Electronic check           70.70        151.65
# 5           Electronic check           99.65        820.50
# 6               Mailed check           25.75           NaN
# 7    Credit card (automatic)           56.05           NaN
# 8           Electronic check          104.80       3046.05
# 9               Mailed check           25.35           NaN

# %%
sample_telecom_contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           1869 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7032 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 440.3+ KB

# %%
query = 'SELECT * FROM telecom.personal;'

sample_telecom_personal = pd.read_sql_query(query, connection)
sample_telecom_personal.head(10)
# Out:
# <ipython-input-8-7797c0d4a0b5>:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sample_telecom_personal = pd.read_sql_query(query, connection)
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# 5  9305-CDSKC  Female              0      No         No
# 6  1452-KIOVK    Male              0      No        Yes
# 7  6713-OKOMC  Female              0      No         No
# 8  7892-POOKP  Female              0     Yes         No
# 9  6388-TABGU    Male              0      No        Yes

# %%
sample_telecom_personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
query = 'SELECT * FROM telecom.internet;'

sample_telecom_internet = pd.read_sql_query(query, connection)
sample_telecom_internet.head(10)
# Out:
# <ipython-input-10-a0531a9eca3f>:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sample_telecom_internet = pd.read_sql_query(query, connection)
#            c1               c2              c3            c4  \
# 0  customerID  InternetService  OnlineSecurity  OnlineBackup
# 1  7590-VHVEG              DSL              No           Yes
# 2  5575-GNVDE              DSL             Yes            No
# 3  3668-QPYBK              DSL             Yes           Yes
# 4  7795-CFOCW              DSL             Yes            No
# 5  9237-HQITU      Fiber optic              No            No
# 6  9305-CDSKC      Fiber optic              No            No
# 7  1452-KIOVK      Fiber optic              No           Yes
# 8  6713-OKOMC              DSL             Yes            No
# 9  7892-POOKP      Fiber optic              No            No
#
#                  c5           c6           c7               c8
# 0  DeviceProtection  TechSupport  StreamingTV  StreamingMovies
# 1                No           No           No               No
# 2               Yes           No           No               No
# 3                No           No           No               No
# 4               Yes          Yes           No               No
# 5                No           No           No               No
# 6               Yes           No          Yes              Yes
# 7                No           No          Yes               No
# 8                No           No           No               No
# 9               Yes          Yes          Yes              Yes

# %%
sample_telecom_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5518 entries, 0 to 5517
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c1      5518 non-null   object
#  1   c2      5518 non-null   object
#  2   c3      5518 non-null   object
#  3   c4      5518 non-null   object
#  4   c5      5518 non-null   object
#  5   c6      5518 non-null   object
#  6   c7      5518 non-null   object
#  7   c8      5518 non-null   object
# dtypes: object(8)
# memory usage: 345.0+ KB

# %% [markdown]
# **Вывод:**
#
# В данном шаги нами были загружены необходимые библиотеки для исследования, а также выведены файлы, содержащиеся в базе данных.

# %% [markdown]
# # Шаг 2. Исследовательский анализ и предобработка данных

# %%
#Переименуем столбцы, удалим нулевой объект
sample_telecom_internet = sample_telecom_internet.rename(columns={'c1':'customerID', 'c2':'InternetService',
                         'c3':'OnlineSecurity', 'c4':'OnlineBackup',
                         'c5':'DeviceProtection', 'c6':'TechSupport',
                         'c7':'StreamingTV', 'c8':'StreamingMovies'}).drop([0]).reset_index(drop=True)
sample_telecom_internet.head()
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No

# %%
query = 'SELECT * FROM telecom.phone;'

sample_telecom_phone = pd.read_sql_query(query, connection)
sample_telecom_phone.head(10)
# Out:
# <ipython-input-13-87057cd8d309>:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sample_telecom_phone = pd.read_sql_query(query, connection)
#            c1             c2
# 0  customerID  MultipleLines
# 1  5575-GNVDE             No
# 2  3668-QPYBK             No
# 3  9237-HQITU             No
# 4  9305-CDSKC            Yes
# 5  1452-KIOVK            Yes
# 6  7892-POOKP            Yes
# 7  6388-TABGU             No
# 8  9763-GRSKD             No
# 9  7469-LKBCI             No

# %%
sample_telecom_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362 entries, 0 to 6361
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c1      6362 non-null   object
#  1   c2      6362 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %%
#переименуем столбцы, удалим 0 объект
sample_telecom_phone = sample_telecom_phone.rename(columns={'c1':'customerID', 'c2':'MultipleLines'}).drop([0]).reset_index(drop=True)
sample_telecom_phone.head()
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %%
print(f'Размер таблицы: {sample_telecom_contract.shape}\n')
print(f'Типы данных таблицы: \n{sample_telecom_contract.dtypes}\n')
print(f'Пропусков в таблице: \n{sample_telecom_contract.isna().sum()}\n')
print(f'Дубликатов в таблице: {sample_telecom_contract.duplicated().sum()}\n')
# Out:
# Размер таблицы: (7043, 8)
#
# Типы данных таблицы:
# customerID           object
# BeginDate            object
# EndDate              object
# Type                 object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object
#
# Пропусков в таблице:
# customerID             0
# BeginDate              0
# EndDate             5174
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges          11
# dtype: int64
#
# Дубликатов в таблице: 0

# %%
print(f'Размер таблицы: {sample_telecom_personal.shape}\n')
print(f'Типы данных таблицы: \n{sample_telecom_personal.dtypes}\n')
print(f'Пропусков в таблице: \n{sample_telecom_personal.isna().sum()}\n')
print(f'Дубликатов в таблице: {sample_telecom_personal.duplicated().sum()}\n')
# Out:
# Размер таблицы: (7043, 5)
#
# Типы данных таблицы:
# customerID       object
# gender           object
# SeniorCitizen     int64
# Partner          object
# Dependents       object
# dtype: object
#
# Пропусков в таблице:
# customerID       0
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# dtype: int64
#
# Дубликатов в таблице: 0

# %%
print(f'Размер таблицы: {sample_telecom_internet.shape}\n')
print(f'Типы данных таблицы: \n{sample_telecom_internet.dtypes}\n')
print(f'Пропусков в таблице: \n{sample_telecom_internet.isna().sum()}\n')
print(f'Дубликатов в таблице: {sample_telecom_internet.duplicated().sum()}\n')
# Out:
# Размер таблицы: (5517, 8)
#
# Типы данных таблицы:
# customerID          object
# InternetService     object
# OnlineSecurity      object
# OnlineBackup        object
# DeviceProtection    object
# TechSupport         object
# StreamingTV         object
# StreamingMovies     object
# dtype: object
#
# Пропусков в таблице:
# customerID          0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64
#
# Дубликатов в таблице: 0

# %%
print(f'Размер таблицы: {sample_telecom_phone.shape}\n')
print(f'Типы данных таблицы: \n{sample_telecom_phone.dtypes}\n')
print(f'Пропусков в таблице: \n{sample_telecom_phone.isna().sum()}\n')
print(f'Дубликатов в таблице: {sample_telecom_phone.duplicated().sum()}\n')
# Out:
# Размер таблицы: (6361, 2)
#
# Типы данных таблицы:
# customerID       object
# MultipleLines    object
# dtype: object
#
# Пропусков в таблице:
# customerID       0
# MultipleLines    0
# dtype: int64
#
# Дубликатов в таблице: 0

# %%
sample_telecom_contract[sample_telecom_contract['TotalCharges'].isna()] #Изучим пропуски в таблице Total Charges
# Out:
#       customerID   BeginDate EndDate      Type PaperlessBilling  \
# 0     4472-LVYGI  2020-02-01    None  Two year              Yes
# 1     3115-CZMZD  2020-02-01    None  Two year               No
# 3     5709-LVOEQ  2020-02-01    None  Two year               No
# 6     4367-NUYAO  2020-02-01    None  Two year               No
# 7     1371-DWPAZ  2020-02-01    None  Two year               No
# 9     3213-VVOLG  2020-02-01    None  Two year               No
# 10    2923-ARZLG  2020-02-01    None  One year              Yes
# 11    2775-SEFEE  2020-02-01    None  Two year              Yes
# 4408  7644-OMVMY  2020-02-01    None  Two year               No
# 5160  2520-SGTTA  2020-02-01    None  Two year               No
# 6839  4075-WKNIU  2020-02-01    None  Two year               No
#
#                   PaymentMethod  MonthlyCharges  TotalCharges
# 0     Bank transfer (automatic)           52.55           NaN
# 1                  Mailed check           20.25           NaN
# 3                  Mailed check           80.85           NaN
# 6                  Mailed check           25.75           NaN
# 7       Credit card (automatic)           56.05           NaN
# 9                  Mailed check           25.35           NaN
# 10                 Mailed check           19.70           NaN
# 11    Bank transfer (automatic)           61.90           NaN
# 4408               Mailed check           19.85           NaN
# 5160               Mailed check           20.00           NaN
# 6839               Mailed check           73.35           NaN

# %%
#Исправим пропуски
sample_telecom_contract['TotalCharges'] = sample_telecom_contract['TotalCharges'].fillna(0)
sample_telecom_contract.isna().sum()
# Out:
# customerID             0
# BeginDate              0
# EndDate             5174
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# dtype: int64

# %%
#Проверим клиентов на аномалии (у которых есть итоговая сумма и которые не отключились)
sample_telecom_contract[(sample_telecom_contract['EndDate'].isna()) & (sample_telecom_contract['TotalCharges']>0)]
# Out:
#       customerID   BeginDate EndDate            Type PaperlessBilling  \
# 280   1106-HRLKZ  2019-01-28    None        Two year               No
# 546   2430-RRYUW  2019-04-03    None        One year              Yes
# 605   8879-XUAHX  2019-04-19    None        Two year              Yes
# 841   8631-XVRZL  2019-01-26    None        One year              Yes
# 878   4324-BZCKL  2019-08-15    None  Month-to-month              Yes
# ...          ...         ...     ...             ...              ...
# 7038  2569-WGERO  2019-01-21    None        Two year              Yes
# 7039  6840-RESVB  2019-02-26    None        One year              Yes
# 7040  2234-XADUH  2019-09-02    None        One year              Yes
# 7041  4801-JZAZL  2019-06-26    None  Month-to-month              Yes
# 7042  3186-AJIEK  2019-04-18    None        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges  TotalCharges
# 280                Mailed check           19.60        808.95
# 546                Mailed check           54.80       3465.70
# 605            Electronic check          116.25       8564.75
# 841                Mailed check           20.15        163.70
# 878                Mailed check           55.55        551.30
# ...                         ...             ...           ...
# 7038  Bank transfer (automatic)           21.15       1419.40
# 7039               Mailed check           84.80       1990.50
# 7040    Credit card (automatic)          103.20       7362.90
# 7041           Electronic check           29.60        346.45
# 7042  Bank transfer (automatic)          105.65       6844.50
#
# [5163 rows x 8 columns]

# %% [markdown]
# Мы видим 2 ошибки. 1я Клиент ушёл и у нас не отмечена дата окончания срока действия оговора `EndDate`.
# 2я - Клиент пользуется услугой, но не имеются его общие расходы `TotalCharges`.

# %%
def hist_box(df, col):
    fig,ax = plt.subplots(2,1, sharex=True, figsize=(6,6),
                          gridspec_kw={'height_ratios': [3, 1]})

    sns.histplot(data=df,x=col,bins=100,
                 ax=ax[0]).set(title=f'Distribution of {col}')

    sns.boxplot(data=df, x=col, ax=ax[1])

    return plt.show();

# %%
hist_box(sample_telecom_contract,'TotalCharges')

# %%
hist_box(sample_telecom_contract,'MonthlyCharges')

# %%
#Исправим итоговую сумму
def corrected_TotalCharges(dataframe):
    correction = sample_telecom_contract['EndDate'].isna()
    dataframe.loc[correction, 'TotalCharges'] = 0
    return dataframe

# %%
correction  = corrected_TotalCharges(sample_telecom_contract)

sample_telecom_contract[sample_telecom_contract['EndDate'].isna()]
# Out:
#       customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0     4472-LVYGI  2020-02-01    None        Two year              Yes
# 1     3115-CZMZD  2020-02-01    None        Two year               No
# 3     5709-LVOEQ  2020-02-01    None        Two year               No
# 6     4367-NUYAO  2020-02-01    None        Two year               No
# 7     1371-DWPAZ  2020-02-01    None        Two year               No
# ...          ...         ...     ...             ...              ...
# 7038  2569-WGERO  2019-01-21    None        Two year              Yes
# 7039  6840-RESVB  2019-02-26    None        One year              Yes
# 7040  2234-XADUH  2019-09-02    None        One year              Yes
# 7041  4801-JZAZL  2019-06-26    None  Month-to-month              Yes
# 7042  3186-AJIEK  2019-04-18    None        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges  TotalCharges
# 0     Bank transfer (automatic)           52.55           0.0
# 1                  Mailed check           20.25           0.0
# 3                  Mailed check           80.85           0.0
# 6                  Mailed check           25.75           0.0
# 7       Credit card (automatic)           56.05           0.0
# ...                         ...             ...           ...
# 7038  Bank transfer (automatic)           21.15           0.0
# 7039               Mailed check           84.80           0.0
# 7040    Credit card (automatic)          103.20           0.0
# 7041           Electronic check           29.60           0.0
# 7042  Bank transfer (automatic)          105.65           0.0
#
# [5174 rows x 8 columns]

# %%
#Исправим дату конца договора
def end_contract(dataframe):
    if dataframe['EndDate'] is None:
        dataframe['target'] = 0
        dataframe['EndDate'] = '2020-02-01'
    return dataframe

# %%
sample_telecom_contract = sample_telecom_contract.apply(end_contract, axis=1)
sample_telecom_contract['EndDate'] = pd.to_datetime(sample_telecom_contract['EndDate'])
sample_telecom_contract['BeginDate'] = pd.to_datetime(sample_telecom_contract['BeginDate'])
sample_telecom_contract['target'] = sample_telecom_contract['target'].fillna(1).astype(int)
sample_telecom_contract.head()
# Out:
#    BeginDate    EndDate  MonthlyCharges PaperlessBilling  \
# 0 2020-02-01 2020-02-01           52.55              Yes
# 1 2020-02-01 2020-02-01           20.25               No
# 2 2018-08-09 2019-12-01           53.85              Yes
# 3 2020-02-01 2020-02-01           80.85               No
# 4 2019-01-26 2019-11-01           70.70              Yes
#
#                PaymentMethod  TotalCharges            Type  customerID  target
# 0  Bank transfer (automatic)          0.00        Two year  4472-LVYGI       0
# 1               Mailed check          0.00        Two year  3115-CZMZD       0
# 2               Mailed check        108.15  Month-to-month  3668-QPYBK       1
# 3               Mailed check          0.00        Two year  5709-LVOEQ       0
# 4           Electronic check        151.65  Month-to-month  9237-HQITU       1

# %%
#исправим итоговую сумму
def corrected_TotalCharges_2(dataframe):
    if dataframe['Type'] == 'Month-to-month':
        value = (dataframe['EndDate'] - dataframe['BeginDate']).days / 30 * dataframe['MonthlyCharges']
        dataframe['TotalCharges'] = value
    return dataframe

# %%
sample_telecom_contract = sample_telecom_contract.apply(corrected_TotalCharges_2, axis=1)

# %%
sample_telecom_contract.head()
# Out:
#    BeginDate    EndDate  MonthlyCharges PaperlessBilling  \
# 0 2020-02-01 2020-02-01           52.55              Yes
# 1 2020-02-01 2020-02-01           20.25               No
# 2 2018-08-09 2019-12-01           53.85              Yes
# 3 2020-02-01 2020-02-01           80.85               No
# 4 2019-01-26 2019-11-01           70.70              Yes
#
#                PaymentMethod  TotalCharges            Type  customerID  target
# 0  Bank transfer (automatic)         0.000        Two year  4472-LVYGI       0
# 1               Mailed check         0.000        Two year  3115-CZMZD       0
# 2               Mailed check       859.805  Month-to-month  3668-QPYBK       1
# 3               Mailed check         0.000        Two year  5709-LVOEQ       0
# 4           Electronic check       657.510  Month-to-month  9237-HQITU       1

# %%
sample_telecom_contract.tail()
# Out:
#       BeginDate    EndDate  MonthlyCharges PaperlessBilling  \
# 7038 2019-01-21 2020-02-01           21.15              Yes
# 7039 2019-02-26 2020-02-01           84.80              Yes
# 7040 2019-09-02 2020-02-01          103.20              Yes
# 7041 2019-06-26 2020-02-01           29.60              Yes
# 7042 2019-04-18 2020-02-01          105.65              Yes
#
#                   PaymentMethod  TotalCharges            Type  customerID  \
# 7038  Bank transfer (automatic)      0.000000        Two year  2569-WGERO
# 7039               Mailed check      0.000000        One year  6840-RESVB
# 7040    Credit card (automatic)      0.000000        One year  2234-XADUH
# 7041           Electronic check    217.066667  Month-to-month  4801-JZAZL
# 7042  Bank transfer (automatic)      0.000000        Two year  3186-AJIEK
#
#       target
# 7038       0
# 7039       0
# 7040       0
# 7041       0
# 7042       0

# %%
#Проверка временного интервала
# Минимальная и максимальная дата для столбца 'BeginDate'
begin_date_min = sample_telecom_contract['BeginDate'].min()
begin_date_max = sample_telecom_contract['BeginDate'].max()

# Минимальная и максимальная дата для столбца 'EndDate'
end_date_min = sample_telecom_contract['EndDate'].min()
end_date_max = sample_telecom_contract['EndDate'].max()

print("Минимальная дата для 'BeginDate':", begin_date_min)
print("Максимальная дата для 'BeginDate':", begin_date_max)
print("Минимальная дата для 'EndDate':", end_date_min)
print("Максимальная дата для 'EndDate':", end_date_max)
# Out:
# Минимальная дата для 'BeginDate': 2018-04-17 00:00:00
# Максимальная дата для 'BeginDate': 2020-02-01 00:00:00
# Минимальная дата для 'EndDate': 2019-10-01 00:00:00
# Максимальная дата для 'EndDate': 2020-02-01 00:00:00

# %%
hist_box(sample_telecom_contract,'TotalCharges')

# %%
hist_box(sample_telecom_contract,'MonthlyCharges')

# %%
#Объединяем всё в один датафейм
df = sample_telecom_personal.merge(sample_telecom_contract, on ='customerID', how='inner')
df = df.merge(sample_telecom_internet, on ='customerID', how = 'outer')
df = df.merge(sample_telecom_phone, on ='customerID', how = 'outer')
df.name = 'data'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   BeginDate         7043 non-null   datetime64[ns]
#  6   EndDate           7043 non-null   datetime64[ns]
#  7   MonthlyCharges    7043 non-null   float64
#  8   PaperlessBilling  7043 non-null   object
#  9   PaymentMethod     7043 non-null   object
#  10  TotalCharges      7043 non-null   float64
#  11  Type              7043 non-null   object
#  12  target            7043 non-null   int64
#  13  InternetService   5517 non-null   object
#  14  OnlineSecurity    5517 non-null   object
#  15  OnlineBackup      5517 non-null   object
#  16  DeviceProtection  5517 non-null   object
#  17  TechSupport       5517 non-null   object
#  18  StreamingTV       5517 non-null   object
#  19  StreamingMovies   5517 non-null   object
#  20  MultipleLines     6361 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(15)
# memory usage: 1.2+ MB

# %%
df.isna().sum() #Проверим данные на количество пропусков
# Out:
# customerID             0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# BeginDate              0
# EndDate                0
# MonthlyCharges         0
# PaperlessBilling       0
# PaymentMethod          0
# TotalCharges           0
# Type                   0
# target                 0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# MultipleLines        682
# dtype: int64

# %%
#заполним имеющиеся пропуски наиболее часто повторяющимся значением
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer.fit(df[df.columns[13:,]])

df[df.columns[13:,]] = imputer.transform(df[df.columns[13:,]])

# %%
#Заполним пропуски

# Создаём объект SimpleImputer с стратегией 'most_frequent'
imputer = SimpleImputer(strategy='most_frequent')

# Выберем подмножество столбцов
columns_to_impute = df.columns[13:]

# Применяем SimpleImputer к выбранным столбцам
imputer.fit(df[columns_to_impute])

# Заполним пропуски
df[columns_to_impute] = imputer.transform(df[columns_to_impute])

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# BeginDate           0
# EndDate             0
# MonthlyCharges      0
# PaperlessBilling    0
# PaymentMethod       0
# TotalCharges        0
# Type                0
# target              0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# MultipleLines       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   BeginDate         7043 non-null   datetime64[ns]
#  6   EndDate           7043 non-null   datetime64[ns]
#  7   MonthlyCharges    7043 non-null   float64
#  8   PaperlessBilling  7043 non-null   object
#  9   PaymentMethod     7043 non-null   object
#  10  TotalCharges      7043 non-null   float64
#  11  Type              7043 non-null   object
#  12  target            7043 non-null   int64
#  13  InternetService   7043 non-null   object
#  14  OnlineSecurity    7043 non-null   object
#  15  OnlineBackup      7043 non-null   object
#  16  DeviceProtection  7043 non-null   object
#  17  TechSupport       7043 non-null   object
#  18  StreamingTV       7043 non-null   object
#  19  StreamingMovies   7043 non-null   object
#  20  MultipleLines     7043 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(15)
# memory usage: 1.2+ MB

# %%
# Заменим все значения в категориальный признаках (Yes/No) числовыми:
for column in df:
    tmp = df[column].unique()
    tmp.sort()
    if list(tmp) == ['No', 'Yes']:
        df[column] = (df[column] == 'Yes').astype('int')
        df[column] = df[column].astype('int')

# %%
#Посмотрим результат замены

df['TotalCharges'].unique()
# Out:
# array([276.61      ,   0.        , 859.805     , ..., 796.14666667,
#        626.97666667, 217.06666667])

# %%
#Рассмотрим зависимость целевого признака от других признаков
def plot_countplot(data, features, target_column, drop_columns=[]):
    data = df.drop(drop_columns, axis=1)

    for feature in features:
        plt.figure(figsize=(10, 5))
        plt.title(f'Dependency of Target on Feature: {feature}')
        sns.countplot(x=feature, hue=target_column, data=data)
        plt.show()

categorical_features = df.columns[2:-2]
target_column = 'target'
drop_columns = []

plot_countplot(df, categorical_features, target_column, drop_columns)

# %% [markdown]
# Исходя из вышеприведённых графиков, мы можем вывести типичного клиента, который будет отказываться от услуг связи. Он совершает ежемесячные переводы на счёт, подключается к Интернету через оптическому волокну, холост, без семьи, без услуг тех. поддежки.

# %%
#Построим также матрицу корреляций признаков
#fig, ax = plt.subplots(figsize=(15,7))
#sns.heatmap(df.corr(), annot=True)
#plt.tight_layout()
#plt.show()

# %% [markdown]
# Наблюдается сильная зависимость между Monthly Charges и StreamingTV +  StreamingMovies + довольно весомая MultipleLines.
#
# Также наблюдается сильная зависисость между StreamingMovies и StreamingTV, а также между MultipleLines с MonthlyCharges.

# %% [markdown]
# **Вывод:**
#
# В ходе предоработки данных мы проверили датасеты на пропуски, дубликаты и пустые значения. Дубликатов обнаружено не было, однако были пропуски в `EndDate` и `TotalCharges`. Пропуски в `EndDate` а пропуски в `TotalCharges` мы решили заполнить нулями, поскольку был небольшой процент от выборки в 11 строк. При рассмотрении столбца `EndDate` мы заметили 2 ошибки, а именно, что были данные, где клиент ушёл и у нас не отмечена дата окончания срока действия договора `EndDate`. Другая - Клиент пользуется услугой, но не имеются его общие расходы `TotalCharges`. В итоге мы решили исправить итоговую сумму и дату конца договора.
#
# Далее мы заметили пропуски из-за несоответствия размерности строк. В итоге мы решили заполнить имеющиеся пропуски наиболее часто повторяющимся значением. Затем мы объединили таблицы в единый датасет и опредилили портреттипичного клиента, который готов расторгнуть договор с компанией по оказываемым услугами рассмотрели взаимозависимости меду признаками на матрице корреляций признаков.

# %%
# !pip install phik
# Out:
# Collecting phik
#   Downloading phik-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from phik) (1.23.5)
# Requirement already satisfied: scipy>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from phik) (1.11.3)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from phik) (1.5.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from phik) (3.7.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.1->phik) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)
# Installing collected packages: phik
# Successfully installed phik-0.12.3

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
phik_overview = df.phik_matrix()
phik_overview.round(2)
# Out:
# interval columns not set, guessing: ['SeniorCitizen', 'Partner', 'Dependents', 'MonthlyCharges', 'PaperlessBilling', 'TotalCharges', 'target', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines']
# /usr/local/lib/python3.10/dist-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable customerID is large: 7043. Are you sure this is not an interval variable? Analysis for pairs of variables including customerID can be slow.
#   warnings.warn(
#                   customerID  gender  SeniorCitizen  Partner  Dependents  \
# customerID               1.0    1.00           1.00     1.00        1.00
# gender                   1.0    1.00           0.00     0.00        0.00
# SeniorCitizen            1.0    0.00           1.00     0.02        0.32
# Partner                  1.0    0.00           0.02     1.00        0.65
# Dependents               1.0    0.00           0.32     0.65        1.00
# BeginDate                1.0    0.09           0.14     0.14        0.08
# EndDate                  1.0    0.00           0.12     0.12        0.13
# MonthlyCharges           1.0    0.01           0.30     0.20        0.18
# PaperlessBilling         1.0    0.00           0.24     0.01        0.17
# PaymentMethod            1.0    0.00           0.29     0.24        0.22
# TotalCharges             1.0    0.03           0.20     0.08        0.14
# Type                     1.0    0.00           0.09     0.18        0.15
# target                   1.0    0.00           0.23     0.23        0.25
# InternetService          1.0    0.00           0.17     0.00        0.08
# OnlineSecurity           1.0    0.02           0.06     0.22        0.12
# OnlineBackup             1.0    0.01           0.10     0.22        0.03
# DeviceProtection         1.0    0.00           0.09     0.24        0.01
# TechSupport              1.0    0.00           0.09     0.19        0.10
# StreamingTV              1.0    0.00           0.16     0.19        0.02
# StreamingMovies          1.0    0.00           0.19     0.18        0.06
# MultipleLines            1.0    0.00           0.22     0.22        0.03
#
#                   BeginDate  EndDate  MonthlyCharges  PaperlessBilling  \
# customerID             1.00     1.00            1.00              1.00
# gender                 0.09     0.00            0.01              0.00
# SeniorCitizen          0.14     0.12            0.30              0.24
# Partner                0.14     0.12            0.20              0.01
# Dependents             0.08     0.13            0.18              0.17
# BeginDate              1.00     0.52            0.19              0.04
# EndDate                0.52     1.00            0.32              0.16
# MonthlyCharges         0.19     0.32            1.00              0.47
# PaperlessBilling       0.04     0.16            0.47              1.00
# PaymentMethod          0.10     0.21            0.40              0.37
# TotalCharges           0.61     0.45            0.48              0.23
# Type                   0.13     0.36            0.39              0.11
# target                 0.49     1.00            0.36              0.30
# InternetService        0.00     0.10            0.95              0.10
# OnlineSecurity         0.11     0.14            0.55              0.00
# OnlineBackup           0.00     0.07            0.63              0.20
# DeviceProtection       0.08     0.05            0.67              0.16
# TechSupport            0.00     0.13            0.58              0.06
# StreamingTV            0.06     0.05            0.84              0.34
# StreamingMovies        0.03     0.05            0.83              0.33
# MultipleLines          0.06     0.03            0.68              0.25
#
#                   PaymentMethod  ...  Type  target  InternetService  \
# customerID                 1.00  ...  1.00    1.00             1.00
# gender                     0.00  ...  0.00    0.00             0.00
# SeniorCitizen              0.29  ...  0.09    0.23             0.17
# Partner                    0.24  ...  0.18    0.23             0.00
# Dependents                 0.22  ...  0.15    0.25             0.08
# BeginDate                  0.10  ...  0.13    0.49             0.00
# EndDate                    0.21  ...  0.36    1.00             0.10
# MonthlyCharges             0.40  ...  0.39    0.36             0.95
# PaperlessBilling           0.37  ...  0.11    0.30             0.10
# PaymentMethod              1.00  ...  0.28    0.45             0.16
# TotalCharges               0.24  ...  0.44    0.51             0.35
# Type                       0.28  ...  1.00    0.25             0.04
# target                     0.45  ...  0.25    1.00             0.19
# InternetService            0.16  ...  0.04    0.19             1.00
# OnlineSecurity             0.26  ...  0.15    0.26             0.48
# OnlineBackup               0.28  ...  0.10    0.13             0.24
# DeviceProtection           0.31  ...  0.14    0.10             0.23
# TechSupport                0.27  ...  0.18    0.25             0.47
# StreamingTV                0.38  ...  0.07    0.10             0.02
# StreamingMovies            0.38  ...  0.07    0.09             0.04
# MultipleLines              0.34  ...  0.07    0.06             0.31
#
#                   OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# customerID                  1.00          1.00              1.00         1.00
# gender                      0.02          0.01              0.00         0.00
# SeniorCitizen               0.06          0.10              0.09         0.09
# Partner                     0.22          0.22              0.24         0.19
# Dependents                  0.12          0.03              0.01         0.10
# BeginDate                   0.11          0.00              0.08         0.00
# EndDate                     0.14          0.07              0.05         0.13
# MonthlyCharges              0.55          0.63              0.67         0.58
# PaperlessBilling            0.00          0.20              0.16         0.06
# PaymentMethod               0.26          0.28              0.31         0.27
# TotalCharges                0.12          0.14              0.16         0.15
# Type                        0.15          0.10              0.14         0.18
# target                      0.26          0.13              0.10         0.25
# InternetService             0.48          0.24              0.23         0.47
# OnlineSecurity              1.00          0.43              0.42         0.53
# OnlineBackup                0.43          1.00              0.46         0.45
# DeviceProtection            0.42          0.46              1.00         0.50
# TechSupport                 0.53          0.45              0.50         1.00
# StreamingTV                 0.27          0.43              0.58         0.42
# StreamingMovies             0.29          0.42              0.59         0.42
# MultipleLines               0.15          0.31              0.31         0.16
#
#                   StreamingTV  StreamingMovies  MultipleLines
# customerID               1.00             1.00           1.00
# gender                   0.00             0.00           0.00
# SeniorCitizen            0.16             0.19           0.22
# Partner                  0.19             0.18           0.22
# Dependents               0.02             0.06           0.03
# BeginDate                0.06             0.03           0.06
# EndDate                  0.05             0.05           0.03
# MonthlyCharges           0.84             0.83           0.68
# PaperlessBilling         0.34             0.33           0.25
# PaymentMethod            0.38             0.38           0.34
# TotalCharges             0.33             0.32           0.28
# Type                     0.07             0.07           0.07
# target                   0.10             0.09           0.06
# InternetService          0.02             0.04           0.31
# OnlineSecurity           0.27             0.29           0.15
# OnlineBackup             0.43             0.42           0.31
# DeviceProtection         0.58             0.59           0.31
# TechSupport              0.42             0.42           0.16
# StreamingTV              1.00             0.74           0.39
# StreamingMovies          0.74             1.00           0.39
# MultipleLines            0.39             0.39           1.00
#
# [21 rows x 21 columns]

# %%
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0,
                        vmax=1,
                        color_map="Reds",
                        title=r"correlation $\phi_K$",
                        fontsize_factor=1.5,
                        figsize=(18, 8))
plt.tight_layout()

# %%
df.drop(['BeginDate'], axis=1, inplace=True)
'BeginDate' in df.columns
# Out:
# False

# %%
df.drop(['EndDate'], axis=1, inplace=True)
'EndDate' in df.columns
# Out:
# False

# %%
df['target'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: target, dtype: int64

# %% [markdown]
# # Шаг 3. Обучение моделей

# %%
# Добавим признаки для обучения модели
features = pd.DataFrame(np.c_[np.array(df[['MonthlyCharges', 'TotalCharges',
                                      'SeniorCitizen']])])
target = df['target']
display(features.head())
display(target.head())
# Out:
#        0        1    2
# 0  29.85  276.610  0.0
# 1  56.95    0.000  0.0
# 2  53.85  859.805  0.0
# 3  42.30    0.000  0.0
# 4  70.70  657.510  0.0
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: target, dtype: int64

# %%
# Добавим признаки для обучения модели:
#df_model = df[['Type','PaperlessBilling', 'PaymentMethod','MonthlyCharges', 'target',
#               'SeniorCitizen', 'Partner', 'Dependents', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport']]

#numeric_names = ['MonthlyCharges']

# %%
#features = df_model.drop('target', axis=1)
#target = df_model['target']

features_train, features_test, target_train, target_test = train_test_split(
features, target, test_size=0.25, random_state=RANDOM_STATE, stratify=target)

#Выведем размер выборок
display(features_train.shape)
display(features_test.shape)
display(target_train.shape)
display(target_test.shape)
# Out:
# (5282, 3)
# (1761, 3)
# (5282,)
# (1761,)

# %% [markdown]
# Применим OneHotEncoder чтобы преобразовать категориальные переменные в колчественные

# %%
from sklearn.compose import ColumnTransformer

numerics = list(features.select_dtypes(include=['int64', 'float64']).columns)
categorical = list(features.select_dtypes(include='object').columns)

col_transformer = ColumnTransformer(
                        transformers=[
                            ('scaler', StandardScaler(), numerics),
                            ('ohe', OneHotEncoder(sparse=False, drop='first'), categorical)],
                                remainder="passthrough"
                                  )

col_transformer.fit(features_train)
features_train = col_transformer.transform(features_train)
features_test = col_transformer.transform(features_test)

# %%
#categorical_features = ['PaymentMethod', 'InternetService', 'Type']

#features_train = pd.get_dummies(features_train, columns=categorical_features)

#features_test = pd.get_dummies(features_test, columns=categorical_features)

# %%
#scaler = StandardScaler()

#scaler.fit(features_train[numeric_names])

#features_train[numeric_names] = scaler.transform(features_train[numeric_names])

#features_test[numeric_names] = scaler.transform(features_test[numeric_names])

#print(features_train[numeric_names].sample(10, random_state=RANDOM_STATE))

# %%
const_model = [1 for i in range(len(target_test))]
const_roc_auc = roc_auc_score(target_test.reset_index(drop=True), const_model)
print(const_roc_auc)
# Out:
# 0.5

# %% [markdown]
# **Модель логистической регрессии**

# %%
# %%time

model_lr = LogisticRegression(fit_intercept=True, class_weight='balanced', random_state=RANDOM_STATE, solver='liblinear')

regression_parameters = {'C': [0.1, 1, 10]}

regression_grid = GridSearchCV(model_lr, regression_parameters, scoring='roc_auc', cv=3, error_score='raise')
regression_grid.fit(features_train, target_train)

model_lr.fit(features_train, target_train)
lr_cv_score = pd.Series(cross_val_score(model_lr, features_train, target_train, scoring='roc_auc', cv=3)).mean()

print('Среднее качество модели логистической регрессии на кросс-валидации', lr_cv_score)
# Out:
# Среднее качество модели логистической регрессии на кросс-валидации 0.8427645769183529
# CPU times: user 130 ms, sys: 3.97 ms, total: 134 ms
# Wall time: 141 ms

# %%
lr_params = regression_grid.best_params_
lr_score = regression_grid.score(features_train, target_train)
print(lr_params)
print(lr_score)
# Out:
# {'C': 0.1}
# 0.8447910385752312

# %% [markdown]
# **Модель решающего дерева**

# %%
model_dt = DecisionTreeClassifier(class_weight='balanced', random_state=RANDOM_STATE)

max_depth_values = range(1, 10)
min_impurity_values = np.arange(0.0, 0.01, 0.001)

parameter_combinations = []

for max_depth in max_depth_values:
    for min_impurity in min_impurity_values:
        parameter_combinations.append({
            'criterion': ['gini', 'entropy'],
            'max_depth': [max_depth],
            'min_impurity_decrease': [min_impurity]
        })

#Увеличиваем n_jobs для параллельных вычислений
dt_grid = GridSearchCV(model_dt, parameter_combinations, scoring='roc_auc', n_jobs=-1, cv=8, verbose=10)
dt_grid.fit(features_train, target_train)
# Out:
# Fitting 8 folds for each of 180 candidates, totalling 1440 fits
# GridSearchCV(cv=8,
#              estimator=DecisionTreeClassifier(class_weight='balanced',
#                                               random_state=1022020),
#              n_jobs=-1,
#              param_grid=[{'criterion': ['gini', 'entropy'], 'max_depth': [1],
#                           'min_impurity_decrease': [0.0]},
#                          {'criterion': ['gini', 'entropy'], 'max_depth': [1],
#                           'min_impurity_decrease': [0.001]},
#                          {'criterion': ['gini', 'entropy'], 'max_depth': [1],
#                           'min_impurity_decrease'...
#                          {'criterion': ['gini', 'entropy'], 'max_depth': [3],
#                           'min_impurity_decrease': [0.006]},
#                          {'criterion': ['gini', 'entropy'], 'max_depth': [3],
#                           'min_impurity_decrease': [0.007]},
#                          {'criterion': ['gini', 'entropy'], 'max_depth': [3],
#                           'min_impurity_decrease': [0.008]},
#                          {'criterion': ['gini', 'entropy'], 'max_depth': [3],
#                           'min_impurity_decrease': [0.009000000000000001]}, ...],
#              scoring='roc_auc', verbose=10)

# %%
y_pred_proba = dt_grid.predict_proba(features_test)[:, 1]

# Вычисляем AUC-ROC на тестовом наборе данных
auc_roc = roc_auc_score(target_test, y_pred_proba)
print('AUC-ROC на тестовом наборе данных:', auc_roc)
# Out:
# AUC-ROC на тестовом наборе данных: 0.8607516490208473

# %%
dt_params = dt_grid.best_params_
dt_cv_score = dt_grid.score(features_train, target_train)
print(dt_params)
print(dt_cv_score)
# Out:
# {'criterion': 'entropy', 'max_depth': 4, 'min_impurity_decrease': 0.0}
# 0.8557099026427637

# %% [markdown]
# **Модель случайного леса**

# %%
# %%time

model_rf = RandomForestClassifier(class_weight='balanced', n_jobs=-1)

rf_parameters = {
    'n_estimators': range(20, 40, 5),
    'max_depth': range(4, 8, 2),
    'min_samples_leaf': range(3,5),
    'min_samples_split': range(2,6,2),
}

rf_grid = GridSearchCV(model_rf, rf_parameters, scoring='roc_auc', cv=3)
rf_grid.fit(features_train, target_train)

model_rf.fit(features_train, target_train)
rf_cv_score = pd.Series(cross_val_score(model_rf, features_train, target_train, scoring='roc_auc', cv=3)).mean()

print('Среднее качество модели случайного леса на кросс-валидации', rf_cv_score)
# Out:
# Среднее качество модели случайного леса на кросс-валидации 0.836980381437661
# CPU times: user 15.8 s, sys: 428 ms, total: 16.2 s
# Wall time: 26.2 s

# %%
rf_params = rf_grid.best_params_
rf_score = rf_grid.score(features_train, target_train)
print(rf_params)
print(rf_score)
# Out:
# {'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 25}
# 0.8820026067326501

# %% [markdown]
# **Catboost**

# %%
# %%time

model_cb = CatBoostClassifier(logging_level='Silent', loss_function='Logloss')
parameters_cb = {'max_depth': np.arange(4, 11),
                  'learning_rate':[0.0001, 0.001, 0.01, 0.1, 1],
                  'iterations': [500,1000,1500,2000]}
catboost_grid = GridSearchCV(model_cb,
                             parameters_cb,
                             cv=3,
                             scoring=['roc_auc', 'precision'],
                             refit = 'roc_auc').fit(features_train, target_train)
# Out:
# CPU times: user 39min 11s, sys: 3min 2s, total: 42min 14s
# Wall time: 24min 37s

# %%
cb_cv_score = pd.Series(cross_val_score(model_cb, features_train, target_train, scoring='roc_auc', cv=3)).mean()

print('Среднее качество Catboost на кросс-валидации', cb_cv_score)
# Out:
# Среднее качество Catboost на кросс-валидации 0.8550896287260285

# %%
cb_params = catboost_grid.best_params_
cb_score = catboost_grid.score(features_train, target_train)
print(cb_params)
print(cb_score)
# Out:
# {'iterations': 1000, 'learning_rate': 0.01, 'max_depth': 5}
# 0.8913367501507419

# %%
#from catboost import CatBoostClassifier, Pool, cv

#feature_names = list(features_train.columns)
#cat_features = list(set(feature_names) - set(numeric_names))

#train_pool = Pool(data=features_train,
#                  label=target_train,
#                  cat_features=cat_features,
#                  feature_names=feature_names)
#test_pool = Pool(data=features_test,
#                 label=target_test,
#                 cat_features=cat_features,
#                 feature_names=feature_names)

# %%
#zeroes = df['target'].value_counts()[0]
#ones = df['target'].value_counts()[1]

#print(df['target'].value_counts())

# %%
#%%time

#class_weights = [1, zeroes/ones]

#model_cb = CatBoostClassifier(class_weights=class_weights, iterations=30)

#cb_parameters = {'depth': [4, 8]}

#cb_grid = GridSearchCV(model_cb, cb_parameters, scoring='roc_auc', cv=3)
#cb_grid.fit(features_train, target_train)

#model_cb.fit(features_train, target_train)
#cb_cv_score = pd.Series(cross_val_score(model_cb, features_train, target_train, scoring='roc_auc', cv=3)).mean()

#print('Среднее качество Catboost на кросс-валидации', cb_cv_score)
#print(f'ROC AUC: {roc_auc_cb:.3f}')

# %% [markdown]
# **Модель нейронной сети**

# %%
NN = Sequential()
NN.add(Dense(256, input_shape=(features_train.shape[1],), activation='relu'))
NN.add(BatchNormalization())
NN.add(Dense(256, activation='relu'))
NN.add(BatchNormalization())
NN.add(Dense(128, activation='relu'))
NN.add(BatchNormalization())
NN.add(Dense(1, activation='sigmoid'))  # Используем активацию 'sigmoid' для бинарной классификации

optimizer = Adam(learning_rate=1e-5)

NN.compile(optimizer=optimizer, loss='binary_crossentropy',  # Используем binary_crossentropy для бинарной классификации
           metrics=[tf.keras.metrics.AUC()])

NN.build()

NN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               1024
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 102401 (400.00 KB)
# Trainable params: 101121 (395.00 KB)
# Non-trainable params: 1280 (5.00 KB)
# _________________________________________________________________

# %%
NN.fit(
    features_train, target_train,
    validation_data=(features_test, target_test),
    batch_size=32, epochs=10,
    verbose=2, shuffle=True
)
# Out:
# Epoch 1/10
# 166/166 - 10s - loss: 0.6592 - auc: 0.7260 - val_loss: 0.8106 - val_auc: 0.7257 - 10s/epoch - 62ms/step
# Epoch 2/10
# 166/166 - 1s - loss: 0.5774 - auc: 0.8249 - val_loss: 0.7811 - val_auc: 0.8215 - 1s/epoch - 6ms/step
# Epoch 3/10
# 166/166 - 1s - loss: 0.5503 - auc: 0.8387 - val_loss: 0.6192 - val_auc: 0.8451 - 972ms/epoch - 6ms/step
# Epoch 4/10
# 166/166 - 1s - loss: 0.5405 - auc: 0.8386 - val_loss: 0.5090 - val_auc: 0.8571 - 995ms/epoch - 6ms/step
# Epoch 5/10
# 166/166 - 1s - loss: 0.5245 - auc: 0.8432 - val_loss: 0.4786 - val_auc: 0.8576 - 1s/epoch - 8ms/step
# Epoch 6/10
# 166/166 - 2s - loss: 0.5212 - auc: 0.8367 - val_loss: 0.4700 - val_auc: 0.8563 - 2s/epoch - 9ms/step
# Epoch 7/10
# 166/166 - 1s - loss: 0.5072 - auc: 0.8465 - val_loss: 0.4672 - val_auc: 0.8565 - 1s/epoch - 7ms/step
# Epoch 8/10
# 166/166 - 1s - loss: 0.5082 - auc: 0.8387 - val_loss: 0.4605 - val_auc: 0.8569 - 986ms/epoch - 6ms/step
# Epoch 9/10
# 166/166 - 1s - loss: 0.5022 - auc: 0.8432 - val_loss: 0.4535 - val_auc: 0.8546 - 1s/epoch - 6ms/step
# Epoch 10/10
# 166/166 - 1s - loss: 0.4980 - auc: 0.8399 - val_loss: 0.4416 - val_auc: 0.8554 - 1s/epoch - 6ms/step

# %%
predicted_probabilities = NN.predict(features_test)
# Out:
# 56/56 [==============================] - 0s 2ms/step

# %%
predicted_classes = (predicted_probabilities > 0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(target_test, predicted_classes)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7791027825099376

# %% [markdown]
# **Вывод:**
#
# На даном шаге была разделена выбока на обучающую и тестовую в соотношении 1 к 4. Было рассмотрено 5 моделей и были выявлены лучшие показатели метрик с помощью кросс-валидации. Также была создана константная модель для сравнения с другими моделями.
#
# Были получены следующие результаты по метрике кросс-валидации:
#
# * Константная модель: 0.5
# * Логистическая регрессия: 0.8267865677897556
# * Решающее дерево: 0.8267865677897556
# * Случайный лес: 0.8442402789828962
# * Catboost: 0.8407154911246084
#
# Лучше всего себя показала модель логистической регрессии и Catboost. Поскольку мы можем протестировать только одну модель, выберем Catboost поскольку он способен обрабатывать сложные нелинейные зависимости и автоматически управлять категориальными признаками.

# %% [markdown]
# # Шаг 4. Тестирование модели

# %%
#%%time

#from sklearn.model_selection import StratifiedKFold

#model_cb = CatBoostClassifier(logging_level='Silent', loss_function='Logloss')

#parameters_cb = {
#    'max_depth': [5],
#    'learning_rate': [0.01],
#    'iterations': [500]
#}

#catboost_grid = GridSearchCV(
#    model_cb,
#    parameters_cb,
#    cv=3,
#    scoring=['roc_auc', 'precision'],
#    refit='roc_auc'
#)

#cb_cv_score = pd.Series(cross_val_score(model_cb, features_train, target_train, scoring='roc_auc', cv=3)).mean()

#print('Среднее качество Catboost на кросс-валидации', cb_cv_score)

# %%
model = CatBoostClassifier(logging_level='Silent',
                           loss_function='Logloss',
                           iterations = 500,
                           learning_rate = 0.01,
                           max_depth = 4).fit(features_train, target_train)
predictions = model.predict(features_test)

# %%
y_pred_proba = model.predict_proba(features_test)[:, 1]

# Вычисляем AUC-ROC на тестовом наборе данных
auc_roc = roc_auc_score(target_test, y_pred_proba)
print('AUC-ROC на тестовом наборе данных:', round(auc_roc, 2))
# Out:
# AUC-ROC на тестовом наборе данных: 0.86

# %%
from sklearn.model_selection import StratifiedKFold

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
train_roc_auc_scores_nn = cross_val_score(model, features_train, target_train, cv=kfold, scoring='roc_auc')

print(f'Mean ROC-AUC: {np.mean(train_roc_auc_scores_nn)}')
# Out:
# Mean ROC-AUC: 0.8605830268371427

# %% [markdown]
# Попробуем улучшить параметры нашей модели Catboost через ресемплинг.

# %%
#from sklearn.utils import resample # сделаем upsampling через resample:

#data = pd.concat([features_train, target_train], axis=1)

#not_fraud = data[data['target'] == 0]
#fraud = data[data['target'] == 1]

#fraud_upsampled = resample(
#    fraud,
#    replace=True,
#    n_samples=len(not_fraud),
#    random_state=RANDOM_STATE)

#upsampled = pd.concat([not_fraud, fraud_upsampled])

#upsampled['target'].value_counts()

# %%
#from sklearn.utils import resample

#data = pd.concat([pd.DataFrame(features_train), pd.Series(target_train, name='target')], axis=1)

#not_fraud = data[data['target'] == 0]
#fraud = data[data['target'] == 1]

#fraud_oversampled = resample(
#    fraud,
#    replace=True,
#    n_samples=len(not_fraud),
#    random_state=RANDOM_STATE)

#oversampled = pd.concat([not_fraud, fraud_oversampled])

#oversampled['target'].value_counts()

# %%
#from imblearn.over_sampling import SMOTE

#sm = SMOTE(random_state=RANDOM_STATE)
#features_oversampled, target_oversampled = sm.fit_resample(features_train, target_train)

# Задайте сетку гиперпараметров для GridSearchCV
#param_grids = {
#    'iterations': [500],
#    'learning_rate': [0.1],
#    'max_depth': [4],
#}

# Создайте классификатор CatBoostClassifier
#model = CatBoostClassifier(
#    loss_function='Logloss',
#    eval_metric='AUC',
#    task_type="CPU",
#    verbose=0,
#    random_seed=RANDOM_STATE
#)

# Выполните Grid Search
#gs_result = GridSearchCV(
#    estimator=model,
#    param_grid=param_grids,
#    cv=5,
#    scoring='roc_auc',
#    n_jobs=-1
#)

#gs_result.fit(features_oversampled, target_oversampled)

#best_model = gs_result.best_estimator_

# Оцените модель на тестовых данных
#predictions = best_model.predict(features_test)
#roc_auc = roc_auc_score(target_test, predictions)

#print("Результаты Grid Search для Catboost с перераспределенными данными:")
#print("\nЛучшие параметры:\n", gs_result.best_params_)
#print("\nЛучший ROC-AUC при перекрестной проверке:\n", gs_result.best_score_)
#print("\nROC-AUC на тестовых данных:\n", roc_auc)

# %%
#target_oversampled = oversampled['target']
#features_oversampled = oversampled.drop(['target'], axis=1)

# %%
#from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV

# Определение параметров для Randomized Search
#param_grids = {
#    'iterations': [500],
#    'learning_rate': [0.1],
#    'max_depth': [4],
    # Другие гиперпараметры CatBoost
#}

# Создание модели CatBoost
#model = CatBoostClassifier(
#    loss_function='Logloss',
#    eval_metric='AUC',
#    task_type="CPU",
#    verbose=0,
#    random_seed=RANDOM_STATE
#)

# Стратифицированная K-Fold кросс-валидация
#cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# Randomized Search для настройки гиперпараметров
#rs_result = RandomizedSearchCV(
#    estimator=model,
#    param_distributions=param_grids,
#    cv=cv,
#    scoring='roc_auc',
#    n_jobs=-1,
#    n_iter=10
#)

#rs_result.fit(features_oversampled, target_oversampled)

#best_model = rs_result.best_estimator_

#predictions = best_model.predict(features_test)

#print("Результаты Grid Search для Catboost с перераспределенными данными:")
#print("\nЛучший ROC-AUC при перекрестной проверке:\n", rs_result.best_score_)
#print("\nROC-AUC на тестовых данных:\n", roc_auc)

# %% [markdown]
# Проверим на адекватность нашу модель. Для этого используем фиктивный классификатор DummyClassifier. Он покажет вероятность успеха даже при угадывании. Чтобы признать модель адекватной, нужно, чтобы показатели метрик были выше тех, которые получатся у фиктивного классификатора. Так как от значения параметра strategy может поменяться результат, переберём их  и для сравнения будем учитывать лучший результат.

# %%
dummy_classifier = DummyClassifier(strategy="stratified")
dummy_classifier.fit(features_train, target_train)

predicted_probabilities = dummy_classifier.predict_proba(features_train)

roc_auc = roc_auc_score(target_train, predicted_probabilities[:, 1])

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.495371303145727

# %% [markdown]
# **Вывод:**
#
# Поскольку наилучшей моделью себя показала во время обучения Catboost, мы её использовали для тестирования. Мы получили значение метрики ROC AUC 0.86, что больше заявленного по условию задачи (0.85) Благодаря применению метода балансировки класса Upsampling нам удалось повысить метрику качества модели. Также мы проверили модель на дамми-ловушку.

# %%
predicted_probalities = model.predict_proba(features_test)[:, 1]

fpr, tpr, thresholds = roc_curve(target_test, predicted_probalities)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')

plt.show()

# %%
predictions = model.predict(features_test)

labels = [0, 1]
plt.subplots(figsize=(6, 6))
sns.heatmap(confusion_matrix(target_test, predictions),
            xticklabels=labels,
            yticklabels=labels,
            annot=True,
            fmt="1.0f",
            cbar=False,
            annot_kws={"size": 20})
plt.title("Confusion matrix", fontsize=30)
plt.xlabel(
    f"model Catboost аccuracy: {accuracy_score(target_test, predictions)}",
    fontsize=30)
plt.show()

# %%
feature_names = [f'feature_{i}' for i in range(features_train.shape[1])]

model = CatBoostClassifier(random_state=RANDOM_STATE)
model.fit(features_train, target_train)
importances = model.feature_importances_
model_importances = pd.Series(importances, index=feature_names)

std = np.std([model.feature_importances_ for tree in str(1000)], axis=0)

fig, ax = plt.subplots(figsize=(10,7))
model_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
# Out:
# Learning rate set to 0.020969
# 0:	learn: 0.6771158	total: 7.77ms	remaining: 7.76s
# 1:	learn: 0.6542432	total: 14.3ms	remaining: 7.12s
# 2:	learn: 0.6301939	total: 18.6ms	remaining: 6.17s
# 3:	learn: 0.6101889	total: 24.6ms	remaining: 6.12s
# 4:	learn: 0.5860862	total: 27.5ms	remaining: 5.48s
# 5:	learn: 0.5728100	total: 34.1ms	remaining: 5.65s
# 6:	learn: 0.5619922	total: 38.7ms	remaining: 5.49s
# 7:	learn: 0.5467613	total: 44.9ms	remaining: 5.57s
# 8:	learn: 0.5382643	total: 51.2ms	remaining: 5.63s
# 9:	learn: 0.5307459	total: 55.8ms	remaining: 5.52s
# 10:	learn: 0.5231455	total: 60.5ms	remaining: 5.43s
# 11:	learn: 0.5124705	total: 65.1ms	remaining: 5.36s
# 12:	learn: 0.5029647	total: 70.8ms	remaining: 5.37s
# 13:	learn: 0.4961583	total: 75.8ms	remaining: 5.34s
# 14:	learn: 0.4853315	total: 81ms	remaining: 5.32s
# 15:	learn: 0.4780777	total: 86.3ms	remaining: 5.31s
# 16:	learn: 0.4724565	total: 89.2ms	remaining: 5.16s
# 17:	learn: 0.4683285	total: 94.5ms	remaining: 5.16s
# 18:	learn: 0.4643563	total: 101ms	remaining: 5.19s
# 19:	learn: 0.4550174	total: 107ms	remaining: 5.23s
# 20:	learn: 0.4500662	total: 113ms	remaining: 5.28s
# 21:	learn: 0.4448347	total: 117ms	remaining: 5.18s
# 22:	learn: 0.4403685	total: 122ms	remaining: 5.17s
# 23:	learn: 0.4382726	total: 129ms	remaining: 5.26s
# 24:	learn: 0.4360641	total: 133ms	remaining: 5.17s
# 25:	learn: 0.4337075	total: 138ms	remaining: 5.17s
# 26:	learn: 0.4315365	total: 143ms	remaining: 5.16s
# 27:	learn: 0.4292915	total: 149ms	remaining: 5.17s
# 28:	learn: 0.4268777	total: 153ms	remaining: 5.13s
# 29:	learn: 0.4241875	total: 160ms	remaining: 5.17s
# 30:	learn: 0.4185455	total: 165ms	remaining: 5.14s
# 31:	learn: 0.4171788	total: 170ms	remaining: 5.14s
# 32:	learn: 0.4161506	total: 174ms	remaining: 5.09s
# 33:	learn: 0.4150111	total: 180ms	remaining: 5.11s
# 34:	learn: 0.4125446	total: 184ms	remaining: 5.08s
# 35:	learn: 0.4120026	total: 193ms	remaining: 5.18s
# 36:	learn: 0.4074528	total: 198ms	remaining: 5.16s
# 37:	learn: 0.4062168	total: 204ms	remaining: 5.16s
# 38:	learn: 0.4040974	total: 209ms	remaining: 5.14s
# 39:	learn: 0.4034419	total: 214ms	remaining: 5.13s
# 40:	learn: 0.4025253	total: 219ms	remaining: 5.12s
# 41:	learn: 0.4023229	total: 223ms	remaining: 5.09s
# 42:	learn: 0.4009057	total: 227ms	remaining: 5.04s
# 43:	learn: 0.4004379	total: 235ms	remaining: 5.11s
# 44:	learn: 0.3983290	total: 239ms	remaining: 5.06s
# 45:	learn: 0.3957080	total: 244ms	remaining: 5.07s
# 46:	learn: 0.3953270	total: 250ms	remaining: 5.07s
# 47:	learn: 0.3941843	total: 255ms	remaining: 5.05s
# 48:	learn: 0.3930111	total: 260ms	remaining: 5.05s
# 49:	learn: 0.3926291	total: 266ms	remaining: 5.04s
# 50:	learn: 0.3920703	total: 271ms	remaining: 5.04s
# 51:	learn: 0.3918146	total: 276ms	remaining: 5.03s
# 52:	learn: 0.3896749	total: 281ms	remaining: 5.02s
# 53:	learn: 0.3881134	total: 286ms	remaining: 5s
# 54:	learn: 0.3868487	total: 291ms	remaining: 4.99s
# 55:	learn: 0.3865953	total: 296ms	remaining: 4.99s
# 56:	learn: 0.3860035	total: 300ms	remaining: 4.97s
# 57:	learn: 0.3855081	total: 306ms	remaining: 4.96s
# 58:	learn: 0.3841124	total: 311ms	remaining: 4.96s
# 59:	learn: 0.3836960	total: 317ms	remaining: 4.97s
# 60:	learn: 0.3835007	total: 322ms	remaining: 4.95s
# 61:	learn: 0.3831287	total: 327ms	remaining: 4.95s
# 62:	learn: 0.3827790	total: 332ms	remaining: 4.93s
# 63:	learn: 0.3825354	total: 337ms	remaining: 4.92s
# 64:	learn: 0.3822249	total: 342ms	remaining: 4.91s
# 65:	learn: 0.3819351	total: 347ms	remaining: 4.91s
# 66:	learn: 0.3817992	total: 352ms	remaining: 4.9s
# 67:	learn: 0.3815285	total: 357ms	remaining: 4.89s
# 68:	learn: 0.3810520	total: 362ms	remaining: 4.88s
# 69:	learn: 0.3794915	total: 367ms	remaining: 4.87s
# 70:	learn: 0.3792948	total: 372ms	remaining: 4.87s
# 71:	learn: 0.3782778	total: 383ms	remaining: 4.94s
# 72:	learn: 0.3780136	total: 388ms	remaining: 4.93s
# 73:	learn: 0.3772094	total: 393ms	remaining: 4.92s
# 74:	learn: 0.3765703	total: 398ms	remaining: 4.91s
# 75:	learn: 0.3760491	total: 402ms	remaining: 4.89s
# 76:	learn: 0.3754595	total: 407ms	remaining: 4.88s
# 77:	learn: 0.3753024	total: 411ms	remaining: 4.86s
# 78:	learn: 0.3751722	total: 416ms	remaining: 4.85s
# 79:	learn: 0.3748760	total: 420ms	remaining: 4.83s
# 80:	learn: 0.3746384	total: 425ms	remaining: 4.83s
# 81:	learn: 0.3744401	total: 431ms	remaining: 4.83s
# 82:	learn: 0.3743783	total: 435ms	remaining: 4.81s
# 83:	learn: 0.3743375	total: 441ms	remaining: 4.81s
# 84:	learn: 0.3741946	total: 445ms	remaining: 4.79s
# 85:	learn: 0.3732058	total: 450ms	remaining: 4.79s
# 86:	learn: 0.3731029	total: 456ms	remaining: 4.78s
# 87:	learn: 0.3722236	total: 460ms	remaining: 4.77s
# 88:	learn: 0.3717170	total: 466ms	remaining: 4.76s
# 89:	learn: 0.3716128	total: 472ms	remaining: 4.77s
# 90:	learn: 0.3715026	total: 481ms	remaining: 4.8s
# 91:	learn: 0.3714039	total: 487ms	remaining: 4.81s
# 92:	learn: 0.3710103	total: 494ms	remaining: 4.82s
# 93:	learn: 0.3707237	total: 500ms	remaining: 4.82s
# 94:	learn: 0.3702437	total: 505ms	remaining: 4.81s
# 95:	learn: 0.3701395	total: 510ms	remaining: 4.8s
# 96:	learn: 0.3699776	total: 516ms	remaining: 4.8s
# 97:	learn: 0.3698628	total: 521ms	remaining: 4.8s
# 98:	learn: 0.3696682	total: 527ms	remaining: 4.8s
# 99:	learn: 0.3695086	total: 535ms	remaining: 4.81s
# 100:	learn: 0.3693759	total: 539ms	remaining: 4.8s
# 101:	learn: 0.3686640	total: 546ms	remaining: 4.81s
# 102:	learn: 0.3685471	total: 551ms	remaining: 4.8s
# 103:	learn: 0.3678891	total: 558ms	remaining: 4.8s
# 104:	learn: 0.3677339	total: 564ms	remaining: 4.8s
# 105:	learn: 0.3676329	total: 578ms	remaining: 4.88s
# 106:	learn: 0.3670623	total: 582ms	remaining: 4.86s
# 107:	learn: 0.3669478	total: 590ms	remaining: 4.87s
# 108:	learn: 0.3668587	total: 596ms	remaining: 4.87s
# 109:	learn: 0.3663130	total: 601ms	remaining: 4.87s
# 110:	learn: 0.3661881	total: 607ms	remaining: 4.86s
# 111:	learn: 0.3661808	total: 611ms	remaining: 4.84s
# 112:	learn: 0.3660313	total: 616ms	remaining: 4.83s
# 113:	learn: 0.3658708	total: 623ms	remaining: 4.84s
# 114:	learn: 0.3657582	total: 628ms	remaining: 4.83s
# 115:	learn: 0.3656532	total: 634ms	remaining: 4.83s
# 116:	learn: 0.3655860	total: 639ms	remaining: 4.83s
# 117:	learn: 0.3654196	total: 647ms	remaining: 4.83s
# 118:	learn: 0.3653245	total: 651ms	remaining: 4.82s
# 119:	learn: 0.3652490	total: 656ms	remaining: 4.81s
# 120:	learn: 0.3651350	total: 661ms	remaining: 4.8s
# 121:	learn: 0.3649161	total: 667ms	remaining: 4.8s
# 122:	learn: 0.3648214	total: 670ms	remaining: 4.78s
# 123:	learn: 0.3647582	total: 673ms	remaining: 4.76s
# 124:	learn: 0.3646249	total: 680ms	remaining: 4.76s
# 125:	learn: 0.3645094	total: 684ms	remaining: 4.75s
# 126:	learn: 0.3640921	total: 691ms	remaining: 4.75s
# 127:	learn: 0.3639861	total: 697ms	remaining: 4.75s
# 128:	learn: 0.3639037	total: 704ms	remaining: 4.75s
# 129:	learn: 0.3638064	total: 708ms	remaining: 4.74s
# 130:	learn: 0.3637455	total: 715ms	remaining: 4.74s
# 131:	learn: 0.3637206	total: 719ms	remaining: 4.73s
# 132:	learn: 0.3636289	total: 725ms	remaining: 4.72s
# 133:	learn: 0.3634899	total: 730ms	remaining: 4.71s
# 134:	learn: 0.3633788	total: 735ms	remaining: 4.71s
# 135:	learn: 0.3633163	total: 741ms	remaining: 4.71s
# 136:	learn: 0.3632448	total: 748ms	remaining: 4.71s
# 137:	learn: 0.3631557	total: 755ms	remaining: 4.71s
# 138:	learn: 0.3631168	total: 758ms	remaining: 4.7s
# 139:	learn: 0.3630070	total: 764ms	remaining: 4.69s
# 140:	learn: 0.3628931	total: 770ms	remaining: 4.69s
# 141:	learn: 0.3627840	total: 778ms	remaining: 4.7s
# 142:	learn: 0.3626279	total: 783ms	remaining: 4.69s
# 143:	learn: 0.3625077	total: 793ms	remaining: 4.71s
# 144:	learn: 0.3624217	total: 800ms	remaining: 4.72s
# 145:	learn: 0.3620384	total: 807ms	remaining: 4.72s
# 146:	learn: 0.3619249	total: 816ms	remaining: 4.73s
# 147:	learn: 0.3618197	total: 819ms	remaining: 4.71s
# 148:	learn: 0.3617492	total: 828ms	remaining: 4.73s
# 149:	learn: 0.3616319	total: 834ms	remaining: 4.72s
# 150:	learn: 0.3615692	total: 838ms	remaining: 4.71s
# 151:	learn: 0.3612406	total: 840ms	remaining: 4.69s
# 152:	learn: 0.3611729	total: 842ms	remaining: 4.66s
# 153:	learn: 0.3610498	total: 845ms	remaining: 4.64s
# 154:	learn: 0.3609648	total: 847ms	remaining: 4.62s
# 155:	learn: 0.3609118	total: 848ms	remaining: 4.59s
# 156:	learn: 0.3607301	total: 851ms	remaining: 4.57s
# 157:	learn: 0.3606522	total: 853ms	remaining: 4.54s
# 158:	learn: 0.3603520	total: 855ms	remaining: 4.52s
# 159:	learn: 0.3602707	total: 857ms	remaining: 4.5s
# 160:	learn: 0.3602080	total: 860ms	remaining: 4.48s
# 161:	learn: 0.3600811	total: 862ms	remaining: 4.46s
# 162:	learn: 0.3600029	total: 864ms	remaining: 4.44s
# 163:	learn: 0.3598332	total: 866ms	remaining: 4.42s
# 164:	learn: 0.3597250	total: 869ms	remaining: 4.4s
# 165:	learn: 0.3595696	total: 871ms	remaining: 4.38s
# 166:	learn: 0.3594875	total: 874ms	remaining: 4.36s
# 167:	learn: 0.3594090	total: 876ms	remaining: 4.34s
# 168:	learn: 0.3593192	total: 879ms	remaining: 4.32s
# 169:	learn: 0.3592699	total: 881ms	remaining: 4.3s
# 170:	learn: 0.3591874	total: 883ms	remaining: 4.28s
# 171:	learn: 0.3591461	total: 885ms	remaining: 4.26s
# 172:	learn: 0.3591066	total: 887ms	remaining: 4.24s
# 173:	learn: 0.3589979	total: 889ms	remaining: 4.22s
# 174:	learn: 0.3589147	total: 892ms	remaining: 4.2s
# 175:	learn: 0.3588334	total: 894ms	remaining: 4.18s
# 176:	learn: 0.3586713	total: 896ms	remaining: 4.17s
# 177:	learn: 0.3585757	total: 898ms	remaining: 4.15s
# 178:	learn: 0.3585021	total: 900ms	remaining: 4.13s
# 179:	learn: 0.3583821	total: 903ms	remaining: 4.11s
# 180:	learn: 0.3582935	total: 905ms	remaining: 4.09s
# 181:	learn: 0.3582189	total: 907ms	remaining: 4.08s
# 182:	learn: 0.3581281	total: 909ms	remaining: 4.06s
# 183:	learn: 0.3580502	total: 912ms	remaining: 4.04s
# 184:	learn: 0.3579432	total: 914ms	remaining: 4.03s
# 185:	learn: 0.3578897	total: 916ms	remaining: 4.01s
# 186:	learn: 0.3578354	total: 918ms	remaining: 3.99s
# 187:	learn: 0.3577489	total: 920ms	remaining: 3.98s
# 188:	learn: 0.3576745	total: 923ms	remaining: 3.96s
# 189:	learn: 0.3575758	total: 925ms	remaining: 3.94s
# 190:	learn: 0.3574965	total: 927ms	remaining: 3.93s
# 191:	learn: 0.3574090	total: 929ms	remaining: 3.91s
# 192:	learn: 0.3573515	total: 931ms	remaining: 3.89s
# 193:	learn: 0.3572987	total: 934ms	remaining: 3.88s
# 194:	learn: 0.3572267	total: 936ms	remaining: 3.86s
# 195:	learn: 0.3571521	total: 938ms	remaining: 3.85s
# 196:	learn: 0.3570752	total: 940ms	remaining: 3.83s
# 197:	learn: 0.3570538	total: 942ms	remaining: 3.81s
# 198:	learn: 0.3568527	total: 944ms	remaining: 3.8s
# 199:	learn: 0.3567728	total: 947ms	remaining: 3.79s
# 200:	learn: 0.3567212	total: 949ms	remaining: 3.77s
# 201:	learn: 0.3566998	total: 950ms	remaining: 3.75s
# 202:	learn: 0.3566440	total: 952ms	remaining: 3.74s
# 203:	learn: 0.3565431	total: 956ms	remaining: 3.73s
# 204:	learn: 0.3564649	total: 961ms	remaining: 3.73s
# 205:	learn: 0.3564087	total: 963ms	remaining: 3.71s
# 206:	learn: 0.3563283	total: 965ms	remaining: 3.69s
# 207:	learn: 0.3562433	total: 967ms	remaining: 3.68s
# 208:	learn: 0.3561518	total: 969ms	remaining: 3.67s
# 209:	learn: 0.3560728	total: 972ms	remaining: 3.65s
# 210:	learn: 0.3559071	total: 974ms	remaining: 3.64s
# 211:	learn: 0.3558040	total: 976ms	remaining: 3.63s
# 212:	learn: 0.3557738	total: 979ms	remaining: 3.62s
# 213:	learn: 0.3557471	total: 981ms	remaining: 3.6s
# 214:	learn: 0.3557308	total: 983ms	remaining: 3.59s
# 215:	learn: 0.3556619	total: 985ms	remaining: 3.58s
# 216:	learn: 0.3555448	total: 988ms	remaining: 3.56s
# 217:	learn: 0.3554592	total: 990ms	remaining: 3.55s
# 218:	learn: 0.3554393	total: 992ms	remaining: 3.54s
# 219:	learn: 0.3553752	total: 994ms	remaining: 3.52s
# 220:	learn: 0.3552774	total: 997ms	remaining: 3.51s
# 221:	learn: 0.3552449	total: 1000ms	remaining: 3.5s
# 222:	learn: 0.3551703	total: 1s	remaining: 3.49s
# 223:	learn: 0.3551676	total: 1s	remaining: 3.48s
# 224:	learn: 0.3551390	total: 1s	remaining: 3.46s
# 225:	learn: 0.3550626	total: 1.01s	remaining: 3.45s
# 226:	learn: 0.3550149	total: 1.01s	remaining: 3.44s
# 227:	learn: 0.3549818	total: 1.01s	remaining: 3.43s
# 228:	learn: 0.3549069	total: 1.01s	remaining: 3.42s
# 229:	learn: 0.3548927	total: 1.02s	remaining: 3.4s
# 230:	learn: 0.3548397	total: 1.02s	remaining: 3.39s
# 231:	learn: 0.3547793	total: 1.02s	remaining: 3.38s
# 232:	learn: 0.3547235	total: 1.02s	remaining: 3.37s
# 233:	learn: 0.3546515	total: 1.02s	remaining: 3.36s
# 234:	learn: 0.3545438	total: 1.03s	remaining: 3.35s
# 235:	learn: 0.3544833	total: 1.03s	remaining: 3.33s
# 236:	learn: 0.3544297	total: 1.03s	remaining: 3.32s
# 237:	learn: 0.3543787	total: 1.03s	remaining: 3.31s
# 238:	learn: 0.3543391	total: 1.04s	remaining: 3.3s
# 239:	learn: 0.3542457	total: 1.04s	remaining: 3.3s
# 240:	learn: 0.3541766	total: 1.04s	remaining: 3.29s
# 241:	learn: 0.3541068	total: 1.04s	remaining: 3.27s
# 242:	learn: 0.3540537	total: 1.05s	remaining: 3.26s
# 243:	learn: 0.3540230	total: 1.05s	remaining: 3.25s
# 244:	learn: 0.3539806	total: 1.05s	remaining: 3.24s
# 245:	learn: 0.3539523	total: 1.05s	remaining: 3.23s
# 246:	learn: 0.3538769	total: 1.06s	remaining: 3.22s
# 247:	learn: 0.3538155	total: 1.06s	remaining: 3.21s
# 248:	learn: 0.3535709	total: 1.06s	remaining: 3.2s
# 249:	learn: 0.3535039	total: 1.06s	remaining: 3.19s
# 250:	learn: 0.3534735	total: 1.06s	remaining: 3.18s
# 251:	learn: 0.3534710	total: 1.07s	remaining: 3.17s
# 252:	learn: 0.3533993	total: 1.07s	remaining: 3.16s
# 253:	learn: 0.3533187	total: 1.07s	remaining: 3.15s
# 254:	learn: 0.3532815	total: 1.07s	remaining: 3.14s
# 255:	learn: 0.3532652	total: 1.08s	remaining: 3.13s
# 256:	learn: 0.3531934	total: 1.08s	remaining: 3.13s
# 257:	learn: 0.3530906	total: 1.08s	remaining: 3.12s
# 258:	learn: 0.3530006	total: 1.09s	remaining: 3.11s
# 259:	learn: 0.3529010	total: 1.09s	remaining: 3.1s
# 260:	learn: 0.3528460	total: 1.09s	remaining: 3.09s
# 261:	learn: 0.3528460	total: 1.09s	remaining: 3.08s
# 262:	learn: 0.3527461	total: 1.09s	remaining: 3.07s
# 263:	learn: 0.3527241	total: 1.1s	remaining: 3.06s
# 264:	learn: 0.3526580	total: 1.1s	remaining: 3.05s
# 265:	learn: 0.3526225	total: 1.1s	remaining: 3.04s
# 266:	learn: 0.3525959	total: 1.1s	remaining: 3.03s
# 267:	learn: 0.3525886	total: 1.1s	remaining: 3.02s
# 268:	learn: 0.3525886	total: 1.11s	remaining: 3.01s
# 269:	learn: 0.3525714	total: 1.11s	remaining: 3s
# 270:	learn: 0.3523706	total: 1.11s	remaining: 2.99s
# 271:	learn: 0.3523009	total: 1.11s	remaining: 2.98s
# 272:	learn: 0.3522437	total: 1.11s	remaining: 2.97s
# 273:	learn: 0.3521806	total: 1.12s	remaining: 2.96s
# 274:	learn: 0.3521056	total: 1.12s	remaining: 2.95s
# 275:	learn: 0.3518509	total: 1.12s	remaining: 2.94s
# 276:	learn: 0.3517497	total: 1.12s	remaining: 2.94s
# 277:	learn: 0.3515608	total: 1.13s	remaining: 2.93s
# 278:	learn: 0.3514259	total: 1.13s	remaining: 2.92s
# 279:	learn: 0.3513377	total: 1.13s	remaining: 2.91s
# 280:	learn: 0.3512638	total: 1.13s	remaining: 2.9s
# 281:	learn: 0.3512027	total: 1.14s	remaining: 2.89s
# 282:	learn: 0.3511465	total: 1.14s	remaining: 2.88s
# 283:	learn: 0.3510484	total: 1.14s	remaining: 2.88s
# 284:	learn: 0.3509701	total: 1.14s	remaining: 2.87s
# 285:	learn: 0.3509099	total: 1.15s	remaining: 2.86s
# 286:	learn: 0.3508476	total: 1.15s	remaining: 2.85s
# 287:	learn: 0.3508275	total: 1.15s	remaining: 2.84s
# 288:	learn: 0.3507847	total: 1.16s	remaining: 2.84s
# 289:	learn: 0.3507091	total: 1.16s	remaining: 2.84s
# 290:	learn: 0.3506842	total: 1.16s	remaining: 2.83s
# 291:	learn: 0.3506259	total: 1.16s	remaining: 2.82s
# 292:	learn: 0.3505587	total: 1.17s	remaining: 2.81s
# 293:	learn: 0.3505080	total: 1.17s	remaining: 2.81s
# 294:	learn: 0.3504290	total: 1.17s	remaining: 2.8s
# 295:	learn: 0.3502313	total: 1.17s	remaining: 2.79s
# 296:	learn: 0.3501971	total: 1.18s	remaining: 2.78s
# 297:	learn: 0.3501415	total: 1.18s	remaining: 2.77s
# 298:	learn: 0.3500977	total: 1.18s	remaining: 2.77s
# 299:	learn: 0.3500274	total: 1.18s	remaining: 2.76s
# 300:	learn: 0.3499253	total: 1.19s	remaining: 2.75s
# 301:	learn: 0.3499213	total: 1.19s	remaining: 2.74s
# 302:	learn: 0.3497984	total: 1.19s	remaining: 2.73s
# 303:	learn: 0.3497197	total: 1.19s	remaining: 2.73s
# 304:	learn: 0.3496705	total: 1.19s	remaining: 2.72s
# 305:	learn: 0.3496525	total: 1.2s	remaining: 2.71s
# 306:	learn: 0.3496433	total: 1.2s	remaining: 2.7s
# 307:	learn: 0.3496238	total: 1.2s	remaining: 2.69s
# 308:	learn: 0.3495589	total: 1.2s	remaining: 2.69s
# 309:	learn: 0.3494815	total: 1.2s	remaining: 2.68s
# 310:	learn: 0.3494090	total: 1.21s	remaining: 2.67s
# 311:	learn: 0.3493366	total: 1.21s	remaining: 2.66s
# 312:	learn: 0.3492449	total: 1.21s	remaining: 2.66s
# 313:	learn: 0.3491824	total: 1.21s	remaining: 2.65s
# 314:	learn: 0.3491198	total: 1.22s	remaining: 2.64s
# 315:	learn: 0.3490583	total: 1.22s	remaining: 2.63s
# 316:	learn: 0.3488948	total: 1.22s	remaining: 2.63s
# 317:	learn: 0.3488846	total: 1.22s	remaining: 2.62s
# 318:	learn: 0.3488542	total: 1.22s	remaining: 2.61s
# 319:	learn: 0.3488213	total: 1.23s	remaining: 2.6s
# 320:	learn: 0.3487774	total: 1.23s	remaining: 2.6s
# 321:	learn: 0.3486509	total: 1.23s	remaining: 2.59s
# 322:	learn: 0.3486112	total: 1.23s	remaining: 2.58s
# 323:	learn: 0.3486055	total: 1.23s	remaining: 2.57s
# 324:	learn: 0.3484810	total: 1.24s	remaining: 2.57s
# 325:	learn: 0.3483673	total: 1.24s	remaining: 2.56s
# 326:	learn: 0.3483036	total: 1.24s	remaining: 2.55s
# 327:	learn: 0.3482500	total: 1.24s	remaining: 2.54s
# 328:	learn: 0.3481931	total: 1.24s	remaining: 2.54s
# 329:	learn: 0.3481377	total: 1.25s	remaining: 2.53s
# 330:	learn: 0.3480929	total: 1.25s	remaining: 2.52s
# 331:	learn: 0.3480577	total: 1.25s	remaining: 2.52s
# 332:	learn: 0.3479654	total: 1.25s	remaining: 2.51s
# 333:	learn: 0.3479577	total: 1.25s	remaining: 2.5s
# 334:	learn: 0.3478659	total: 1.26s	remaining: 2.5s
# 335:	learn: 0.3478225	total: 1.26s	remaining: 2.49s
# 336:	learn: 0.3477923	total: 1.26s	remaining: 2.48s
# 337:	learn: 0.3477168	total: 1.26s	remaining: 2.48s
# 338:	learn: 0.3476507	total: 1.27s	remaining: 2.47s
# 339:	learn: 0.3476079	total: 1.27s	remaining: 2.46s
# 340:	learn: 0.3475516	total: 1.27s	remaining: 2.46s
# 341:	learn: 0.3475043	total: 1.27s	remaining: 2.45s
# 342:	learn: 0.3474647	total: 1.27s	remaining: 2.44s
# 343:	learn: 0.3474605	total: 1.28s	remaining: 2.44s
# 344:	learn: 0.3474264	total: 1.28s	remaining: 2.43s
# 345:	learn: 0.3473792	total: 1.28s	remaining: 2.42s
# 346:	learn: 0.3473287	total: 1.28s	remaining: 2.42s
# 347:	learn: 0.3472789	total: 1.29s	remaining: 2.41s
# 348:	learn: 0.3471107	total: 1.29s	remaining: 2.4s
# 349:	learn: 0.3470458	total: 1.29s	remaining: 2.4s
# 350:	learn: 0.3469968	total: 1.29s	remaining: 2.39s
# 351:	learn: 0.3469119	total: 1.29s	remaining: 2.38s
# 352:	learn: 0.3468470	total: 1.3s	remaining: 2.38s
# 353:	learn: 0.3467866	total: 1.3s	remaining: 2.37s
# 354:	learn: 0.3467293	total: 1.3s	remaining: 2.37s
# 355:	learn: 0.3466954	total: 1.3s	remaining: 2.36s
# 356:	learn: 0.3465504	total: 1.31s	remaining: 2.35s
# 357:	learn: 0.3464122	total: 1.31s	remaining: 2.35s
# 358:	learn: 0.3464095	total: 1.31s	remaining: 2.34s
# 359:	learn: 0.3463947	total: 1.31s	remaining: 2.33s
# 360:	learn: 0.3463290	total: 1.31s	remaining: 2.33s
# 361:	learn: 0.3462389	total: 1.32s	remaining: 2.32s
# 362:	learn: 0.3461583	total: 1.32s	remaining: 2.31s
# 363:	learn: 0.3460937	total: 1.32s	remaining: 2.31s
# 364:	learn: 0.3460153	total: 1.32s	remaining: 2.3s
# 365:	learn: 0.3459469	total: 1.33s	remaining: 2.3s
# 366:	learn: 0.3459079	total: 1.33s	remaining: 2.29s
# 367:	learn: 0.3458430	total: 1.33s	remaining: 2.29s
# 368:	learn: 0.3457507	total: 1.33s	remaining: 2.28s
# 369:	learn: 0.3456872	total: 1.34s	remaining: 2.27s
# 370:	learn: 0.3456178	total: 1.34s	remaining: 2.27s
# 371:	learn: 0.3455456	total: 1.34s	remaining: 2.26s
# 372:	learn: 0.3454525	total: 1.34s	remaining: 2.26s
# 373:	learn: 0.3453585	total: 1.35s	remaining: 2.26s
# 374:	learn: 0.3453078	total: 1.35s	remaining: 2.25s
# 375:	learn: 0.3452682	total: 1.35s	remaining: 2.25s
# 376:	learn: 0.3451981	total: 1.35s	remaining: 2.24s
# 377:	learn: 0.3451309	total: 1.36s	remaining: 2.23s
# 378:	learn: 0.3450877	total: 1.36s	remaining: 2.23s
# 379:	learn: 0.3450360	total: 1.36s	remaining: 2.22s
# 380:	learn: 0.3450018	total: 1.36s	remaining: 2.22s
# 381:	learn: 0.3449560	total: 1.37s	remaining: 2.21s
# 382:	learn: 0.3448810	total: 1.37s	remaining: 2.21s
# 383:	learn: 0.3448358	total: 1.37s	remaining: 2.2s
# 384:	learn: 0.3447314	total: 1.37s	remaining: 2.19s
# 385:	learn: 0.3446578	total: 1.38s	remaining: 2.19s
# 386:	learn: 0.3446003	total: 1.38s	remaining: 2.18s
# 387:	learn: 0.3444500	total: 1.38s	remaining: 2.18s
# 388:	learn: 0.3443745	total: 1.38s	remaining: 2.17s
# 389:	learn: 0.3443207	total: 1.39s	remaining: 2.17s
# 390:	learn: 0.3442516	total: 1.39s	remaining: 2.16s
# 391:	learn: 0.3442335	total: 1.39s	remaining: 2.15s
# 392:	learn: 0.3441696	total: 1.39s	remaining: 2.15s
# 393:	learn: 0.3440924	total: 1.39s	remaining: 2.14s
# 394:	learn: 0.3440136	total: 1.4s	remaining: 2.14s
# 395:	learn: 0.3439633	total: 1.4s	remaining: 2.13s
# 396:	learn: 0.3438857	total: 1.4s	remaining: 2.13s
# 397:	learn: 0.3438007	total: 1.4s	remaining: 2.12s
# 398:	learn: 0.3437254	total: 1.41s	remaining: 2.12s
# 399:	learn: 0.3436909	total: 1.41s	remaining: 2.11s
# 400:	learn: 0.3436085	total: 1.41s	remaining: 2.11s
# 401:	learn: 0.3435469	total: 1.41s	remaining: 2.1s
# 402:	learn: 0.3434785	total: 1.41s	remaining: 2.1s
# 403:	learn: 0.3434182	total: 1.42s	remaining: 2.09s
# 404:	learn: 0.3433700	total: 1.42s	remaining: 2.08s
# 405:	learn: 0.3433162	total: 1.42s	remaining: 2.08s
# 406:	learn: 0.3432567	total: 1.42s	remaining: 2.07s
# 407:	learn: 0.3432180	total: 1.43s	remaining: 2.07s
# 408:	learn: 0.3431670	total: 1.43s	remaining: 2.06s
# 409:	learn: 0.3430904	total: 1.43s	remaining: 2.06s
# 410:	learn: 0.3430180	total: 1.43s	remaining: 2.05s
# 411:	learn: 0.3429424	total: 1.43s	remaining: 2.05s
# 412:	learn: 0.3428550	total: 1.44s	remaining: 2.04s
# 413:	learn: 0.3427754	total: 1.44s	remaining: 2.04s
# 414:	learn: 0.3426967	total: 1.44s	remaining: 2.03s
# 415:	learn: 0.3426519	total: 1.44s	remaining: 2.03s
# 416:	learn: 0.3425988	total: 1.45s	remaining: 2.02s
# 417:	learn: 0.3425237	total: 1.45s	remaining: 2.02s
# 418:	learn: 0.3424678	total: 1.45s	remaining: 2.01s
# 419:	learn: 0.3423931	total: 1.45s	remaining: 2s
# 420:	learn: 0.3423148	total: 1.45s	remaining: 2s
# 421:	learn: 0.3422657	total: 1.46s	remaining: 1.99s
# 422:	learn: 0.3421860	total: 1.46s	remaining: 1.99s
# 423:	learn: 0.3421262	total: 1.46s	remaining: 1.98s
# 424:	learn: 0.3420411	total: 1.46s	remaining: 1.98s
# 425:	learn: 0.3419379	total: 1.46s	remaining: 1.97s
# 426:	learn: 0.3418720	total: 1.47s	remaining: 1.97s
# 427:	learn: 0.3418131	total: 1.47s	remaining: 1.96s
# 428:	learn: 0.3417242	total: 1.47s	remaining: 1.96s
# 429:	learn: 0.3415857	total: 1.47s	remaining: 1.95s
# 430:	learn: 0.3415076	total: 1.48s	remaining: 1.95s
# 431:	learn: 0.3414151	total: 1.48s	remaining: 1.94s
# 432:	learn: 0.3413665	total: 1.48s	remaining: 1.94s
# 433:	learn: 0.3412593	total: 1.48s	remaining: 1.93s
# 434:	learn: 0.3412029	total: 1.48s	remaining: 1.93s
# 435:	learn: 0.3411508	total: 1.49s	remaining: 1.92s
# 436:	learn: 0.3410825	total: 1.49s	remaining: 1.92s
# 437:	learn: 0.3410128	total: 1.49s	remaining: 1.91s
# 438:	learn: 0.3409350	total: 1.49s	remaining: 1.91s
# 439:	learn: 0.3408440	total: 1.5s	remaining: 1.9s
# 440:	learn: 0.3407493	total: 1.5s	remaining: 1.9s
# 441:	learn: 0.3406207	total: 1.5s	remaining: 1.89s
# 442:	learn: 0.3405309	total: 1.5s	remaining: 1.89s
# 443:	learn: 0.3404782	total: 1.5s	remaining: 1.89s
# 444:	learn: 0.3404274	total: 1.51s	remaining: 1.88s
# 445:	learn: 0.3403356	total: 1.51s	remaining: 1.88s
# 446:	learn: 0.3402574	total: 1.52s	remaining: 1.88s
# 447:	learn: 0.3401108	total: 1.52s	remaining: 1.88s
# 448:	learn: 0.3400141	total: 1.52s	remaining: 1.87s
# 449:	learn: 0.3399123	total: 1.53s	remaining: 1.86s
# 450:	learn: 0.3398561	total: 1.53s	remaining: 1.86s
# 451:	learn: 0.3397133	total: 1.53s	remaining: 1.85s
# 452:	learn: 0.3396401	total: 1.53s	remaining: 1.85s
# 453:	learn: 0.3395013	total: 1.53s	remaining: 1.85s
# 454:	learn: 0.3394212	total: 1.54s	remaining: 1.85s
# 455:	learn: 0.3393370	total: 1.54s	remaining: 1.84s
# 456:	learn: 0.3392163	total: 1.55s	remaining: 1.84s
# 457:	learn: 0.3391331	total: 1.55s	remaining: 1.83s
# 458:	learn: 0.3389713	total: 1.55s	remaining: 1.83s
# 459:	learn: 0.3389303	total: 1.55s	remaining: 1.82s
# 460:	learn: 0.3388286	total: 1.55s	remaining: 1.82s
# 461:	learn: 0.3387631	total: 1.56s	remaining: 1.81s
# 462:	learn: 0.3386937	total: 1.56s	remaining: 1.81s
# 463:	learn: 0.3386223	total: 1.56s	remaining: 1.8s
# 464:	learn: 0.3384868	total: 1.56s	remaining: 1.8s
# 465:	learn: 0.3384016	total: 1.57s	remaining: 1.8s
# 466:	learn: 0.3383366	total: 1.57s	remaining: 1.79s
# 467:	learn: 0.3382565	total: 1.57s	remaining: 1.79s
# 468:	learn: 0.3381745	total: 1.57s	remaining: 1.78s
# 469:	learn: 0.3380823	total: 1.58s	remaining: 1.78s
# 470:	learn: 0.3380137	total: 1.58s	remaining: 1.77s
# 471:	learn: 0.3379122	total: 1.58s	remaining: 1.77s
# 472:	learn: 0.3377622	total: 1.58s	remaining: 1.76s
# 473:	learn: 0.3376533	total: 1.58s	remaining: 1.76s
# 474:	learn: 0.3375552	total: 1.59s	remaining: 1.75s
# 475:	learn: 0.3375039	total: 1.59s	remaining: 1.75s
# 476:	learn: 0.3374378	total: 1.59s	remaining: 1.75s
# 477:	learn: 0.3373622	total: 1.59s	remaining: 1.74s
# 478:	learn: 0.3372996	total: 1.6s	remaining: 1.74s
# 479:	learn: 0.3372347	total: 1.6s	remaining: 1.73s
# 480:	learn: 0.3371269	total: 1.6s	remaining: 1.73s
# 481:	learn: 0.3370428	total: 1.6s	remaining: 1.72s
# 482:	learn: 0.3369441	total: 1.6s	remaining: 1.72s
# 483:	learn: 0.3368716	total: 1.61s	remaining: 1.71s
# 484:	learn: 0.3367900	total: 1.61s	remaining: 1.71s
# 485:	learn: 0.3367138	total: 1.61s	remaining: 1.71s
# 486:	learn: 0.3366604	total: 1.62s	remaining: 1.7s
# 487:	learn: 0.3365678	total: 1.62s	remaining: 1.7s
# 488:	learn: 0.3365070	total: 1.62s	remaining: 1.69s
# 489:	learn: 0.3364286	total: 1.62s	remaining: 1.69s
# 490:	learn: 0.3363601	total: 1.63s	remaining: 1.69s
# 491:	learn: 0.3362799	total: 1.63s	remaining: 1.68s
# 492:	learn: 0.3361995	total: 1.63s	remaining: 1.68s
# 493:	learn: 0.3361079	total: 1.63s	remaining: 1.67s
# 494:	learn: 0.3359674	total: 1.63s	remaining: 1.67s
# 495:	learn: 0.3358812	total: 1.64s	remaining: 1.66s
# 496:	learn: 0.3357465	total: 1.64s	remaining: 1.66s
# 497:	learn: 0.3356637	total: 1.64s	remaining: 1.65s
# 498:	learn: 0.3355325	total: 1.64s	remaining: 1.65s
# 499:	learn: 0.3354416	total: 1.65s	remaining: 1.65s
# 500:	learn: 0.3353826	total: 1.65s	remaining: 1.64s
# 501:	learn: 0.3352325	total: 1.65s	remaining: 1.64s
# 502:	learn: 0.3351820	total: 1.65s	remaining: 1.63s
# 503:	learn: 0.3351088	total: 1.66s	remaining: 1.63s
# 504:	learn: 0.3350452	total: 1.66s	remaining: 1.63s
# 505:	learn: 0.3349682	total: 1.66s	remaining: 1.62s
# 506:	learn: 0.3348871	total: 1.66s	remaining: 1.62s
# 507:	learn: 0.3348103	total: 1.66s	remaining: 1.61s
# 508:	learn: 0.3347172	total: 1.67s	remaining: 1.61s
# 509:	learn: 0.3346021	total: 1.67s	remaining: 1.6s
# 510:	learn: 0.3345307	total: 1.67s	remaining: 1.6s
# 511:	learn: 0.3344256	total: 1.67s	remaining: 1.59s
# 512:	learn: 0.3343453	total: 1.68s	remaining: 1.59s
# 513:	learn: 0.3342715	total: 1.68s	remaining: 1.59s
# 514:	learn: 0.3342131	total: 1.68s	remaining: 1.58s
# 515:	learn: 0.3341017	total: 1.68s	remaining: 1.58s
# 516:	learn: 0.3340252	total: 1.68s	remaining: 1.57s
# 517:	learn: 0.3339125	total: 1.69s	remaining: 1.57s
# 518:	learn: 0.3338254	total: 1.69s	remaining: 1.56s
# 519:	learn: 0.3337134	total: 1.69s	remaining: 1.56s
# 520:	learn: 0.3336349	total: 1.69s	remaining: 1.56s
# 521:	learn: 0.3335324	total: 1.7s	remaining: 1.55s
# 522:	learn: 0.3334209	total: 1.7s	remaining: 1.55s
# 523:	learn: 0.3332862	total: 1.7s	remaining: 1.54s
# 524:	learn: 0.3332168	total: 1.7s	remaining: 1.54s
# 525:	learn: 0.3331412	total: 1.71s	remaining: 1.54s
# 526:	learn: 0.3330328	total: 1.71s	remaining: 1.53s
# 527:	learn: 0.3329501	total: 1.71s	remaining: 1.53s
# 528:	learn: 0.3328805	total: 1.71s	remaining: 1.52s
# 529:	learn: 0.3328098	total: 1.71s	remaining: 1.52s
# 530:	learn: 0.3327429	total: 1.72s	remaining: 1.52s
# 531:	learn: 0.3326432	total: 1.72s	remaining: 1.51s
# 532:	learn: 0.3325629	total: 1.72s	remaining: 1.51s
# 533:	learn: 0.3324505	total: 1.72s	remaining: 1.5s
# 534:	learn: 0.3323170	total: 1.73s	remaining: 1.5s
# 535:	learn: 0.3322473	total: 1.73s	remaining: 1.5s
# 536:	learn: 0.3321560	total: 1.73s	remaining: 1.49s
# 537:	learn: 0.3320716	total: 1.73s	remaining: 1.49s
# 538:	learn: 0.3319601	total: 1.74s	remaining: 1.49s
# 539:	learn: 0.3318950	total: 1.74s	remaining: 1.48s
# 540:	learn: 0.3318020	total: 1.74s	remaining: 1.48s
# 541:	learn: 0.3317377	total: 1.74s	remaining: 1.47s
# 542:	learn: 0.3316108	total: 1.75s	remaining: 1.47s
# 543:	learn: 0.3315219	total: 1.75s	remaining: 1.47s
# 544:	learn: 0.3314516	total: 1.75s	remaining: 1.46s
# 545:	learn: 0.3313847	total: 1.75s	remaining: 1.46s
# 546:	learn: 0.3313240	total: 1.76s	remaining: 1.46s
# 547:	learn: 0.3312528	total: 1.76s	remaining: 1.45s
# 548:	learn: 0.3311287	total: 1.76s	remaining: 1.45s
# 549:	learn: 0.3310117	total: 1.77s	remaining: 1.45s
# 550:	learn: 0.3308985	total: 1.77s	remaining: 1.44s
# 551:	learn: 0.3308140	total: 1.77s	remaining: 1.44s
# 552:	learn: 0.3307658	total: 1.77s	remaining: 1.43s
# 553:	learn: 0.3306603	total: 1.78s	remaining: 1.43s
# 554:	learn: 0.3305823	total: 1.78s	remaining: 1.43s
# 555:	learn: 0.3304559	total: 1.79s	remaining: 1.43s
# 556:	learn: 0.3303796	total: 1.79s	remaining: 1.43s
# 557:	learn: 0.3302851	total: 1.79s	remaining: 1.42s
# 558:	learn: 0.3301679	total: 1.8s	remaining: 1.42s
# 559:	learn: 0.3300554	total: 1.8s	remaining: 1.41s
# 560:	learn: 0.3299900	total: 1.8s	remaining: 1.41s
# 561:	learn: 0.3298980	total: 1.8s	remaining: 1.4s
# 562:	learn: 0.3298157	total: 1.8s	remaining: 1.4s
# 563:	learn: 0.3297282	total: 1.81s	remaining: 1.4s
# 564:	learn: 0.3296504	total: 1.81s	remaining: 1.39s
# 565:	learn: 0.3295709	total: 1.81s	remaining: 1.39s
# 566:	learn: 0.3294932	total: 1.81s	remaining: 1.38s
# 567:	learn: 0.3294204	total: 1.81s	remaining: 1.38s
# 568:	learn: 0.3293305	total: 1.82s	remaining: 1.38s
# 569:	learn: 0.3292678	total: 1.82s	remaining: 1.37s
# 570:	learn: 0.3291823	total: 1.82s	remaining: 1.37s
# 571:	learn: 0.3291026	total: 1.82s	remaining: 1.36s
# 572:	learn: 0.3290156	total: 1.83s	remaining: 1.36s
# 573:	learn: 0.3289409	total: 1.83s	remaining: 1.36s
# 574:	learn: 0.3288318	total: 1.83s	remaining: 1.35s
# 575:	learn: 0.3287272	total: 1.83s	remaining: 1.35s
# 576:	learn: 0.3286665	total: 1.83s	remaining: 1.34s
# 577:	learn: 0.3285618	total: 1.84s	remaining: 1.34s
# 578:	learn: 0.3284812	total: 1.84s	remaining: 1.34s
# 579:	learn: 0.3283951	total: 1.84s	remaining: 1.33s
# 580:	learn: 0.3283402	total: 1.84s	remaining: 1.33s
# 581:	learn: 0.3282549	total: 1.84s	remaining: 1.32s
# 582:	learn: 0.3281716	total: 1.85s	remaining: 1.32s
# 583:	learn: 0.3280861	total: 1.85s	remaining: 1.32s
# 584:	learn: 0.3280181	total: 1.85s	remaining: 1.31s
# 585:	learn: 0.3279723	total: 1.85s	remaining: 1.31s
# 586:	learn: 0.3279141	total: 1.85s	remaining: 1.3s
# 587:	learn: 0.3278627	total: 1.86s	remaining: 1.3s
# 588:	learn: 0.3277591	total: 1.86s	remaining: 1.3s
# 589:	learn: 0.3276677	total: 1.86s	remaining: 1.29s
# 590:	learn: 0.3275763	total: 1.86s	remaining: 1.29s
# 591:	learn: 0.3274717	total: 1.86s	remaining: 1.28s
# 592:	learn: 0.3274057	total: 1.87s	remaining: 1.28s
# 593:	learn: 0.3273078	total: 1.87s	remaining: 1.28s
# 594:	learn: 0.3272218	total: 1.87s	remaining: 1.27s
# 595:	learn: 0.3271514	total: 1.87s	remaining: 1.27s
# 596:	learn: 0.3270773	total: 1.88s	remaining: 1.27s
# 597:	learn: 0.3270178	total: 1.88s	remaining: 1.26s
# 598:	learn: 0.3269533	total: 1.88s	remaining: 1.26s
# 599:	learn: 0.3268777	total: 1.88s	remaining: 1.26s
# 600:	learn: 0.3268056	total: 1.89s	remaining: 1.25s
# 601:	learn: 0.3267048	total: 1.89s	remaining: 1.25s
# 602:	learn: 0.3266230	total: 1.89s	remaining: 1.25s
# 603:	learn: 0.3265434	total: 1.89s	remaining: 1.24s
# 604:	learn: 0.3264699	total: 1.9s	remaining: 1.24s
# 605:	learn: 0.3263590	total: 1.9s	remaining: 1.23s
# 606:	learn: 0.3262959	total: 1.9s	remaining: 1.23s
# 607:	learn: 0.3262226	total: 1.9s	remaining: 1.23s
# 608:	learn: 0.3261535	total: 1.91s	remaining: 1.22s
# 609:	learn: 0.3260773	total: 1.91s	remaining: 1.22s
# 610:	learn: 0.3260084	total: 1.91s	remaining: 1.22s
# 611:	learn: 0.3259198	total: 1.91s	remaining: 1.21s
# 612:	learn: 0.3258287	total: 1.91s	remaining: 1.21s
# 613:	learn: 0.3257650	total: 1.92s	remaining: 1.21s
# 614:	learn: 0.3256801	total: 1.92s	remaining: 1.2s
# 615:	learn: 0.3255619	total: 1.92s	remaining: 1.2s
# 616:	learn: 0.3254808	total: 1.93s	remaining: 1.2s
# 617:	learn: 0.3254181	total: 1.93s	remaining: 1.19s
# 618:	learn: 0.3253421	total: 1.93s	remaining: 1.19s
# 619:	learn: 0.3252808	total: 1.94s	remaining: 1.19s
# 620:	learn: 0.3252056	total: 1.94s	remaining: 1.18s
# 621:	learn: 0.3251246	total: 1.94s	remaining: 1.18s
# 622:	learn: 0.3250472	total: 1.94s	remaining: 1.18s
# 623:	learn: 0.3249411	total: 1.94s	remaining: 1.17s
# 624:	learn: 0.3248576	total: 1.95s	remaining: 1.17s
# 625:	learn: 0.3247818	total: 1.95s	remaining: 1.16s
# 626:	learn: 0.3246952	total: 1.95s	remaining: 1.16s
# 627:	learn: 0.3246351	total: 1.95s	remaining: 1.16s
# 628:	learn: 0.3245535	total: 1.96s	remaining: 1.15s
# 629:	learn: 0.3244866	total: 1.96s	remaining: 1.15s
# 630:	learn: 0.3244422	total: 1.96s	remaining: 1.15s
# 631:	learn: 0.3243664	total: 1.96s	remaining: 1.14s
# 632:	learn: 0.3242932	total: 1.97s	remaining: 1.14s
# 633:	learn: 0.3242311	total: 1.97s	remaining: 1.14s
# 634:	learn: 0.3241549	total: 1.97s	remaining: 1.13s
# 635:	learn: 0.3240965	total: 1.97s	remaining: 1.13s
# 636:	learn: 0.3240059	total: 1.97s	remaining: 1.13s
# 637:	learn: 0.3239525	total: 1.98s	remaining: 1.12s
# 638:	learn: 0.3238020	total: 1.98s	remaining: 1.12s
# 639:	learn: 0.3237188	total: 1.98s	remaining: 1.11s
# 640:	learn: 0.3236524	total: 1.98s	remaining: 1.11s
# 641:	learn: 0.3235729	total: 1.99s	remaining: 1.11s
# 642:	learn: 0.3234956	total: 1.99s	remaining: 1.1s
# 643:	learn: 0.3234033	total: 1.99s	remaining: 1.1s
# 644:	learn: 0.3233499	total: 1.99s	remaining: 1.1s
# 645:	learn: 0.3232814	total: 2s	remaining: 1.09s
# 646:	learn: 0.3231847	total: 2s	remaining: 1.09s
# 647:	learn: 0.3230603	total: 2s	remaining: 1.09s
# 648:	learn: 0.3229882	total: 2s	remaining: 1.08s
# 649:	learn: 0.3229184	total: 2s	remaining: 1.08s
# 650:	learn: 0.3228759	total: 2.01s	remaining: 1.08s
# 651:	learn: 0.3228115	total: 2.01s	remaining: 1.07s
# 652:	learn: 0.3227446	total: 2.01s	remaining: 1.07s
# 653:	learn: 0.3226571	total: 2.01s	remaining: 1.06s
# 654:	learn: 0.3225781	total: 2.02s	remaining: 1.06s
# 655:	learn: 0.3225076	total: 2.02s	remaining: 1.06s
# 656:	learn: 0.3224434	total: 2.02s	remaining: 1.05s
# 657:	learn: 0.3223841	total: 2.02s	remaining: 1.05s
# 658:	learn: 0.3223327	total: 2.02s	remaining: 1.05s
# 659:	learn: 0.3222660	total: 2.03s	remaining: 1.04s
# 660:	learn: 0.3221988	total: 2.03s	remaining: 1.04s
# 661:	learn: 0.3221258	total: 2.03s	remaining: 1.04s
# 662:	learn: 0.3220594	total: 2.03s	remaining: 1.03s
# 663:	learn: 0.3220189	total: 2.04s	remaining: 1.03s
# 664:	learn: 0.3219235	total: 2.04s	remaining: 1.03s
# 665:	learn: 0.3218586	total: 2.04s	remaining: 1.02s
# 666:	learn: 0.3217887	total: 2.04s	remaining: 1.02s
# 667:	learn: 0.3217165	total: 2.04s	remaining: 1.02s
# 668:	learn: 0.3215988	total: 2.05s	remaining: 1.01s
# 669:	learn: 0.3215476	total: 2.05s	remaining: 1.01s
# 670:	learn: 0.3215010	total: 2.05s	remaining: 1s
# 671:	learn: 0.3214346	total: 2.05s	remaining: 1s
# 672:	learn: 0.3213686	total: 2.06s	remaining: 999ms
# 673:	learn: 0.3212911	total: 2.06s	remaining: 995ms
# 674:	learn: 0.3212256	total: 2.06s	remaining: 992ms
# 675:	learn: 0.3211394	total: 2.06s	remaining: 988ms
# 676:	learn: 0.3210365	total: 2.06s	remaining: 985ms
# 677:	learn: 0.3209876	total: 2.06s	remaining: 981ms
# 678:	learn: 0.3208894	total: 2.07s	remaining: 977ms
# 679:	learn: 0.3208264	total: 2.07s	remaining: 974ms
# 680:	learn: 0.3207330	total: 2.07s	remaining: 970ms
# 681:	learn: 0.3206475	total: 2.07s	remaining: 967ms
# 682:	learn: 0.3205741	total: 2.08s	remaining: 963ms
# 683:	learn: 0.3205204	total: 2.08s	remaining: 960ms
# 684:	learn: 0.3204588	total: 2.08s	remaining: 957ms
# 685:	learn: 0.3203956	total: 2.08s	remaining: 953ms
# 686:	learn: 0.3203178	total: 2.08s	remaining: 950ms
# 687:	learn: 0.3202668	total: 2.09s	remaining: 946ms
# 688:	learn: 0.3202220	total: 2.09s	remaining: 943ms
# 689:	learn: 0.3201452	total: 2.09s	remaining: 940ms
# 690:	learn: 0.3200584	total: 2.09s	remaining: 936ms
# 691:	learn: 0.3200058	total: 2.1s	remaining: 933ms
# 692:	learn: 0.3199425	total: 2.1s	remaining: 929ms
# 693:	learn: 0.3198779	total: 2.1s	remaining: 926ms
# 694:	learn: 0.3197964	total: 2.1s	remaining: 923ms
# 695:	learn: 0.3197103	total: 2.1s	remaining: 919ms
# 696:	learn: 0.3196446	total: 2.11s	remaining: 916ms
# 697:	learn: 0.3195749	total: 2.11s	remaining: 912ms
# 698:	learn: 0.3195279	total: 2.11s	remaining: 909ms
# 699:	learn: 0.3194671	total: 2.11s	remaining: 906ms
# 700:	learn: 0.3193993	total: 2.12s	remaining: 902ms
# 701:	learn: 0.3193250	total: 2.12s	remaining: 899ms
# 702:	learn: 0.3192661	total: 2.12s	remaining: 896ms
# 703:	learn: 0.3191996	total: 2.13s	remaining: 894ms
# 704:	learn: 0.3191490	total: 2.13s	remaining: 890ms
# 705:	learn: 0.3190649	total: 2.13s	remaining: 887ms
# 706:	learn: 0.3190198	total: 2.13s	remaining: 884ms
# 707:	learn: 0.3189393	total: 2.13s	remaining: 880ms
# 708:	learn: 0.3188736	total: 2.14s	remaining: 877ms
# 709:	learn: 0.3187835	total: 2.14s	remaining: 874ms
# 710:	learn: 0.3187054	total: 2.14s	remaining: 870ms
# 711:	learn: 0.3186549	total: 2.14s	remaining: 867ms
# 712:	learn: 0.3185682	total: 2.15s	remaining: 864ms
# 713:	learn: 0.3185197	total: 2.15s	remaining: 860ms
# 714:	learn: 0.3184490	total: 2.15s	remaining: 857ms
# 715:	learn: 0.3183973	total: 2.15s	remaining: 854ms
# 716:	learn: 0.3183602	total: 2.15s	remaining: 850ms
# 717:	learn: 0.3182881	total: 2.16s	remaining: 847ms
# 718:	learn: 0.3182267	total: 2.16s	remaining: 844ms
# 719:	learn: 0.3181672	total: 2.16s	remaining: 840ms
# 720:	learn: 0.3181053	total: 2.16s	remaining: 837ms
# 721:	learn: 0.3180021	total: 2.17s	remaining: 834ms
# 722:	learn: 0.3179170	total: 2.17s	remaining: 831ms
# 723:	learn: 0.3178463	total: 2.17s	remaining: 827ms
# 724:	learn: 0.3177682	total: 2.17s	remaining: 824ms
# 725:	learn: 0.3177016	total: 2.17s	remaining: 821ms
# 726:	learn: 0.3176279	total: 2.18s	remaining: 817ms
# 727:	learn: 0.3175377	total: 2.18s	remaining: 814ms
# 728:	learn: 0.3174632	total: 2.18s	remaining: 811ms
# 729:	learn: 0.3173382	total: 2.18s	remaining: 808ms
# 730:	learn: 0.3172806	total: 2.19s	remaining: 804ms
# 731:	learn: 0.3172216	total: 2.19s	remaining: 801ms
# 732:	learn: 0.3171471	total: 2.19s	remaining: 798ms
# 733:	learn: 0.3170826	total: 2.19s	remaining: 795ms
# 734:	learn: 0.3170075	total: 2.19s	remaining: 791ms
# 735:	learn: 0.3169430	total: 2.2s	remaining: 788ms
# 736:	learn: 0.3168845	total: 2.2s	remaining: 785ms
# 737:	learn: 0.3168190	total: 2.2s	remaining: 782ms
# 738:	learn: 0.3167357	total: 2.2s	remaining: 778ms
# 739:	learn: 0.3166713	total: 2.21s	remaining: 775ms
# 740:	learn: 0.3166156	total: 2.21s	remaining: 772ms
# 741:	learn: 0.3165046	total: 2.21s	remaining: 769ms
# 742:	learn: 0.3164062	total: 2.21s	remaining: 766ms
# 743:	learn: 0.3163362	total: 2.21s	remaining: 762ms
# 744:	learn: 0.3162559	total: 2.22s	remaining: 759ms
# 745:	learn: 0.3162106	total: 2.22s	remaining: 756ms
# 746:	learn: 0.3161688	total: 2.22s	remaining: 753ms
# 747:	learn: 0.3160941	total: 2.22s	remaining: 749ms
# 748:	learn: 0.3160293	total: 2.23s	remaining: 746ms
# 749:	learn: 0.3159372	total: 2.23s	remaining: 743ms
# 750:	learn: 0.3158750	total: 2.23s	remaining: 740ms
# 751:	learn: 0.3157713	total: 2.23s	remaining: 737ms
# 752:	learn: 0.3157148	total: 2.24s	remaining: 733ms
# 753:	learn: 0.3156381	total: 2.24s	remaining: 730ms
# 754:	learn: 0.3155612	total: 2.24s	remaining: 727ms
# 755:	learn: 0.3154762	total: 2.24s	remaining: 724ms
# 756:	learn: 0.3153701	total: 2.25s	remaining: 721ms
# 757:	learn: 0.3152692	total: 2.25s	remaining: 718ms
# 758:	learn: 0.3152360	total: 2.25s	remaining: 714ms
# 759:	learn: 0.3151815	total: 2.25s	remaining: 711ms
# 760:	learn: 0.3151216	total: 2.25s	remaining: 708ms
# 761:	learn: 0.3150505	total: 2.26s	remaining: 705ms
# 762:	learn: 0.3149901	total: 2.26s	remaining: 702ms
# 763:	learn: 0.3148861	total: 2.26s	remaining: 699ms
# 764:	learn: 0.3148163	total: 2.26s	remaining: 696ms
# 765:	learn: 0.3147349	total: 2.27s	remaining: 692ms
# 766:	learn: 0.3146749	total: 2.27s	remaining: 689ms
# 767:	learn: 0.3146037	total: 2.27s	remaining: 686ms
# 768:	learn: 0.3145092	total: 2.27s	remaining: 683ms
# 769:	learn: 0.3144367	total: 2.28s	remaining: 680ms
# 770:	learn: 0.3143507	total: 2.28s	remaining: 677ms
# 771:	learn: 0.3142729	total: 2.28s	remaining: 674ms
# 772:	learn: 0.3142193	total: 2.28s	remaining: 670ms
# 773:	learn: 0.3141462	total: 2.29s	remaining: 667ms
# 774:	learn: 0.3140961	total: 2.29s	remaining: 664ms
# 775:	learn: 0.3140427	total: 2.29s	remaining: 661ms
# 776:	learn: 0.3139660	total: 2.29s	remaining: 658ms
# 777:	learn: 0.3139051	total: 2.29s	remaining: 655ms
# 778:	learn: 0.3138383	total: 2.3s	remaining: 652ms
# 779:	learn: 0.3137785	total: 2.3s	remaining: 648ms
# 780:	learn: 0.3137053	total: 2.3s	remaining: 645ms
# 781:	learn: 0.3136346	total: 2.3s	remaining: 642ms
# 782:	learn: 0.3135850	total: 2.31s	remaining: 639ms
# 783:	learn: 0.3135243	total: 2.31s	remaining: 636ms
# 784:	learn: 0.3134520	total: 2.31s	remaining: 633ms
# 785:	learn: 0.3134088	total: 2.31s	remaining: 630ms
# 786:	learn: 0.3133393	total: 2.31s	remaining: 626ms
# 787:	learn: 0.3132671	total: 2.32s	remaining: 624ms
# 788:	learn: 0.3131936	total: 2.32s	remaining: 621ms
# 789:	learn: 0.3131300	total: 2.32s	remaining: 618ms
# 790:	learn: 0.3130622	total: 2.33s	remaining: 615ms
# 791:	learn: 0.3129939	total: 2.33s	remaining: 612ms
# 792:	learn: 0.3129379	total: 2.33s	remaining: 608ms
# 793:	learn: 0.3128899	total: 2.33s	remaining: 605ms
# 794:	learn: 0.3128205	total: 2.33s	remaining: 602ms
# 795:	learn: 0.3127445	total: 2.34s	remaining: 599ms
# 796:	learn: 0.3126907	total: 2.34s	remaining: 596ms
# 797:	learn: 0.3126257	total: 2.34s	remaining: 593ms
# 798:	learn: 0.3125346	total: 2.34s	remaining: 590ms
# 799:	learn: 0.3124114	total: 2.35s	remaining: 586ms
# 800:	learn: 0.3123487	total: 2.35s	remaining: 583ms
# 801:	learn: 0.3123087	total: 2.35s	remaining: 580ms
# 802:	learn: 0.3122510	total: 2.35s	remaining: 577ms
# 803:	learn: 0.3121801	total: 2.35s	remaining: 574ms
# 804:	learn: 0.3121311	total: 2.36s	remaining: 571ms
# 805:	learn: 0.3121003	total: 2.36s	remaining: 568ms
# 806:	learn: 0.3120360	total: 2.36s	remaining: 565ms
# 807:	learn: 0.3119906	total: 2.36s	remaining: 562ms
# 808:	learn: 0.3119177	total: 2.37s	remaining: 558ms
# 809:	learn: 0.3118459	total: 2.37s	remaining: 555ms
# 810:	learn: 0.3117575	total: 2.37s	remaining: 552ms
# 811:	learn: 0.3117001	total: 2.37s	remaining: 550ms
# 812:	learn: 0.3116275	total: 2.38s	remaining: 547ms
# 813:	learn: 0.3115638	total: 2.38s	remaining: 544ms
# 814:	learn: 0.3114947	total: 2.38s	remaining: 540ms
# 815:	learn: 0.3114512	total: 2.38s	remaining: 537ms
# 816:	learn: 0.3113978	total: 2.38s	remaining: 534ms
# 817:	learn: 0.3113360	total: 2.39s	remaining: 531ms
# 818:	learn: 0.3112897	total: 2.39s	remaining: 528ms
# 819:	learn: 0.3112297	total: 2.39s	remaining: 525ms
# 820:	learn: 0.3111700	total: 2.39s	remaining: 522ms
# 821:	learn: 0.3110829	total: 2.4s	remaining: 519ms
# 822:	learn: 0.3110236	total: 2.4s	remaining: 516ms
# 823:	learn: 0.3109852	total: 2.4s	remaining: 513ms
# 824:	learn: 0.3109273	total: 2.4s	remaining: 510ms
# 825:	learn: 0.3108760	total: 2.4s	remaining: 507ms
# 826:	learn: 0.3108163	total: 2.41s	remaining: 504ms
# 827:	learn: 0.3107513	total: 2.41s	remaining: 501ms
# 828:	learn: 0.3107023	total: 2.41s	remaining: 498ms
# 829:	learn: 0.3106609	total: 2.41s	remaining: 494ms
# 830:	learn: 0.3105996	total: 2.42s	remaining: 491ms
# 831:	learn: 0.3105501	total: 2.42s	remaining: 488ms
# 832:	learn: 0.3104751	total: 2.42s	remaining: 485ms
# 833:	learn: 0.3103716	total: 2.42s	remaining: 482ms
# 834:	learn: 0.3103300	total: 2.42s	remaining: 479ms
# 835:	learn: 0.3102771	total: 2.43s	remaining: 476ms
# 836:	learn: 0.3102365	total: 2.43s	remaining: 473ms
# 837:	learn: 0.3101865	total: 2.43s	remaining: 470ms
# 838:	learn: 0.3101109	total: 2.43s	remaining: 467ms
# 839:	learn: 0.3100283	total: 2.44s	remaining: 464ms
# 840:	learn: 0.3099756	total: 2.44s	remaining: 461ms
# 841:	learn: 0.3099220	total: 2.44s	remaining: 458ms
# 842:	learn: 0.3098485	total: 2.44s	remaining: 455ms
# 843:	learn: 0.3097910	total: 2.44s	remaining: 452ms
# 844:	learn: 0.3097232	total: 2.45s	remaining: 449ms
# 845:	learn: 0.3096529	total: 2.45s	remaining: 446ms
# 846:	learn: 0.3095882	total: 2.45s	remaining: 443ms
# 847:	learn: 0.3095435	total: 2.45s	remaining: 440ms
# 848:	learn: 0.3094928	total: 2.46s	remaining: 437ms
# 849:	learn: 0.3094332	total: 2.46s	remaining: 434ms
# 850:	learn: 0.3093417	total: 2.46s	remaining: 431ms
# 851:	learn: 0.3092723	total: 2.46s	remaining: 428ms
# 852:	learn: 0.3091746	total: 2.46s	remaining: 425ms
# 853:	learn: 0.3090925	total: 2.47s	remaining: 422ms
# 854:	learn: 0.3090050	total: 2.47s	remaining: 419ms
# 855:	learn: 0.3089456	total: 2.47s	remaining: 416ms
# 856:	learn: 0.3088782	total: 2.47s	remaining: 413ms
# 857:	learn: 0.3088139	total: 2.48s	remaining: 410ms
# 858:	learn: 0.3087856	total: 2.48s	remaining: 407ms
# 859:	learn: 0.3087288	total: 2.48s	remaining: 404ms
# 860:	learn: 0.3086874	total: 2.48s	remaining: 401ms
# 861:	learn: 0.3086271	total: 2.48s	remaining: 398ms
# 862:	learn: 0.3085831	total: 2.49s	remaining: 395ms
# 863:	learn: 0.3085321	total: 2.49s	remaining: 392ms
# 864:	learn: 0.3084481	total: 2.49s	remaining: 389ms
# 865:	learn: 0.3083984	total: 2.49s	remaining: 386ms
# 866:	learn: 0.3083355	total: 2.5s	remaining: 383ms
# 867:	learn: 0.3082290	total: 2.5s	remaining: 380ms
# 868:	learn: 0.3081422	total: 2.5s	remaining: 377ms
# 869:	learn: 0.3080935	total: 2.5s	remaining: 374ms
# 870:	learn: 0.3080315	total: 2.51s	remaining: 372ms
# 871:	learn: 0.3079920	total: 2.52s	remaining: 369ms
# 872:	learn: 0.3079418	total: 2.52s	remaining: 367ms
# 873:	learn: 0.3078621	total: 2.52s	remaining: 364ms
# 874:	learn: 0.3078154	total: 2.52s	remaining: 361ms
# 875:	learn: 0.3077335	total: 2.53s	remaining: 358ms
# 876:	learn: 0.3076787	total: 2.53s	remaining: 355ms
# 877:	learn: 0.3076409	total: 2.53s	remaining: 352ms
# 878:	learn: 0.3075799	total: 2.53s	remaining: 349ms
# 879:	learn: 0.3075027	total: 2.54s	remaining: 346ms
# 880:	learn: 0.3074549	total: 2.54s	remaining: 343ms
# 881:	learn: 0.3073763	total: 2.54s	remaining: 340ms
# 882:	learn: 0.3072362	total: 2.54s	remaining: 337ms
# 883:	learn: 0.3071656	total: 2.55s	remaining: 334ms
# 884:	learn: 0.3071135	total: 2.55s	remaining: 331ms
# 885:	learn: 0.3070156	total: 2.55s	remaining: 328ms
# 886:	learn: 0.3069505	total: 2.55s	remaining: 325ms
# 887:	learn: 0.3068806	total: 2.56s	remaining: 322ms
# 888:	learn: 0.3068135	total: 2.56s	remaining: 319ms
# 889:	learn: 0.3067763	total: 2.56s	remaining: 316ms
# 890:	learn: 0.3067019	total: 2.56s	remaining: 313ms
# 891:	learn: 0.3066341	total: 2.56s	remaining: 310ms
# 892:	learn: 0.3065697	total: 2.57s	remaining: 308ms
# 893:	learn: 0.3065135	total: 2.57s	remaining: 305ms
# 894:	learn: 0.3064572	total: 2.57s	remaining: 302ms
# 895:	learn: 0.3064103	total: 2.57s	remaining: 299ms
# 896:	learn: 0.3063654	total: 2.58s	remaining: 296ms
# 897:	learn: 0.3062912	total: 2.58s	remaining: 293ms
# 898:	learn: 0.3062245	total: 2.58s	remaining: 290ms
# 899:	learn: 0.3061667	total: 2.58s	remaining: 287ms
# 900:	learn: 0.3061210	total: 2.58s	remaining: 284ms
# 901:	learn: 0.3060622	total: 2.59s	remaining: 281ms
# 902:	learn: 0.3060192	total: 2.59s	remaining: 278ms
# 903:	learn: 0.3059641	total: 2.59s	remaining: 275ms
# 904:	learn: 0.3059005	total: 2.59s	remaining: 272ms
# 905:	learn: 0.3058456	total: 2.6s	remaining: 269ms
# 906:	learn: 0.3057851	total: 2.6s	remaining: 266ms
# 907:	learn: 0.3057315	total: 2.6s	remaining: 263ms
# 908:	learn: 0.3056724	total: 2.6s	remaining: 260ms
# 909:	learn: 0.3056024	total: 2.6s	remaining: 258ms
# 910:	learn: 0.3055454	total: 2.61s	remaining: 255ms
# 911:	learn: 0.3054875	total: 2.61s	remaining: 252ms
# 912:	learn: 0.3054353	total: 2.61s	remaining: 249ms
# 913:	learn: 0.3053565	total: 2.61s	remaining: 246ms
# 914:	learn: 0.3052962	total: 2.62s	remaining: 243ms
# 915:	learn: 0.3052257	total: 2.62s	remaining: 240ms
# 916:	learn: 0.3051854	total: 2.62s	remaining: 237ms
# 917:	learn: 0.3051055	total: 2.62s	remaining: 234ms
# 918:	learn: 0.3049769	total: 2.62s	remaining: 231ms
# 919:	learn: 0.3049042	total: 2.63s	remaining: 228ms
# 920:	learn: 0.3048534	total: 2.63s	remaining: 226ms
# 921:	learn: 0.3048085	total: 2.63s	remaining: 223ms
# 922:	learn: 0.3047529	total: 2.63s	remaining: 220ms
# 923:	learn: 0.3046736	total: 2.64s	remaining: 217ms
# 924:	learn: 0.3046247	total: 2.64s	remaining: 214ms
# 925:	learn: 0.3045550	total: 2.64s	remaining: 211ms
# 926:	learn: 0.3044730	total: 2.64s	remaining: 208ms
# 927:	learn: 0.3044308	total: 2.65s	remaining: 205ms
# 928:	learn: 0.3043668	total: 2.65s	remaining: 202ms
# 929:	learn: 0.3043260	total: 2.65s	remaining: 199ms
# 930:	learn: 0.3042719	total: 2.65s	remaining: 197ms
# 931:	learn: 0.3042280	total: 2.65s	remaining: 194ms
# 932:	learn: 0.3041768	total: 2.66s	remaining: 191ms
# 933:	learn: 0.3041388	total: 2.66s	remaining: 188ms
# 934:	learn: 0.3040829	total: 2.66s	remaining: 185ms
# 935:	learn: 0.3040302	total: 2.66s	remaining: 182ms
# 936:	learn: 0.3039657	total: 2.66s	remaining: 179ms
# 937:	learn: 0.3039186	total: 2.67s	remaining: 176ms
# 938:	learn: 0.3038523	total: 2.67s	remaining: 173ms
# 939:	learn: 0.3037708	total: 2.67s	remaining: 171ms
# 940:	learn: 0.3037216	total: 2.67s	remaining: 168ms
# 941:	learn: 0.3036555	total: 2.67s	remaining: 165ms
# 942:	learn: 0.3036112	total: 2.68s	remaining: 162ms
# 943:	learn: 0.3035553	total: 2.68s	remaining: 159ms
# 944:	learn: 0.3034462	total: 2.68s	remaining: 156ms
# 945:	learn: 0.3033967	total: 2.68s	remaining: 153ms
# 946:	learn: 0.3033407	total: 2.69s	remaining: 150ms
# 947:	learn: 0.3032571	total: 2.69s	remaining: 147ms
# 948:	learn: 0.3032131	total: 2.69s	remaining: 145ms
# 949:	learn: 0.3031472	total: 2.69s	remaining: 142ms
# 950:	learn: 0.3030728	total: 2.69s	remaining: 139ms
# 951:	learn: 0.3030207	total: 2.7s	remaining: 136ms
# 952:	learn: 0.3029712	total: 2.7s	remaining: 133ms
# 953:	learn: 0.3029131	total: 2.7s	remaining: 130ms
# 954:	learn: 0.3028388	total: 2.7s	remaining: 127ms
# 955:	learn: 0.3027897	total: 2.71s	remaining: 125ms
# 956:	learn: 0.3027380	total: 2.71s	remaining: 122ms
# 957:	learn: 0.3026849	total: 2.71s	remaining: 119ms
# 958:	learn: 0.3026348	total: 2.72s	remaining: 116ms
# 959:	learn: 0.3025635	total: 2.72s	remaining: 113ms
# 960:	learn: 0.3025276	total: 2.72s	remaining: 110ms
# 961:	learn: 0.3024676	total: 2.72s	remaining: 108ms
# 962:	learn: 0.3024160	total: 2.73s	remaining: 105ms
# 963:	learn: 0.3023162	total: 2.73s	remaining: 102ms
# 964:	learn: 0.3022705	total: 2.73s	remaining: 99ms
# 965:	learn: 0.3021973	total: 2.73s	remaining: 96.2ms
# 966:	learn: 0.3021481	total: 2.73s	remaining: 93.3ms
# 967:	learn: 0.3021021	total: 2.74s	remaining: 90.5ms
# 968:	learn: 0.3020366	total: 2.74s	remaining: 87.8ms
# 969:	learn: 0.3019757	total: 2.75s	remaining: 85ms
# 970:	learn: 0.3019284	total: 2.75s	remaining: 82.3ms
# 971:	learn: 0.3018620	total: 2.76s	remaining: 79.4ms
# 972:	learn: 0.3018208	total: 2.76s	remaining: 76.6ms
# 973:	learn: 0.3017676	total: 2.76s	remaining: 73.7ms
# 974:	learn: 0.3016655	total: 2.76s	remaining: 70.9ms
# 975:	learn: 0.3016166	total: 2.77s	remaining: 68ms
# 976:	learn: 0.3015530	total: 2.77s	remaining: 65.2ms
# 977:	learn: 0.3014950	total: 2.77s	remaining: 62.3ms
# 978:	learn: 0.3014256	total: 2.77s	remaining: 59.5ms
# 979:	learn: 0.3013661	total: 2.77s	remaining: 56.6ms
# 980:	learn: 0.3013194	total: 2.78s	remaining: 53.8ms
# 981:	learn: 0.3012655	total: 2.78s	remaining: 51ms
# 982:	learn: 0.3012212	total: 2.78s	remaining: 48.1ms
# 983:	learn: 0.3011583	total: 2.78s	remaining: 45.3ms
# 984:	learn: 0.3011120	total: 2.79s	remaining: 42.4ms
# 985:	learn: 0.3010507	total: 2.79s	remaining: 39.6ms
# 986:	learn: 0.3010038	total: 2.79s	remaining: 36.8ms
# 987:	learn: 0.3009500	total: 2.79s	remaining: 33.9ms
# 988:	learn: 0.3008744	total: 2.8s	remaining: 31.1ms
# 989:	learn: 0.3008302	total: 2.8s	remaining: 28.3ms
# 990:	learn: 0.3007459	total: 2.8s	remaining: 25.4ms
# 991:	learn: 0.3006840	total: 2.8s	remaining: 22.6ms
# 992:	learn: 0.3006533	total: 2.81s	remaining: 19.8ms
# 993:	learn: 0.3006054	total: 2.81s	remaining: 16.9ms
# 994:	learn: 0.3005379	total: 2.81s	remaining: 14.1ms
# 995:	learn: 0.3004713	total: 2.81s	remaining: 11.3ms
# 996:	learn: 0.3004089	total: 2.81s	remaining: 8.47ms
# 997:	learn: 0.3003750	total: 2.82s	remaining: 5.64ms
# 998:	learn: 0.3003245	total: 2.82s	remaining: 2.82ms
# 999:	learn: 0.3002745	total: 2.82s	remaining: 0us

# %% [markdown]
# # Шаг 5. Общий вывод по работе

# %% [markdown]
# 1. На начальном этапе исследования были загружены необходимые библиотеки для исследования, а также выведены файлы, содержащиеся в базе данных.
#
# 2. В ходе предоработки данных проверены датасеты на пропуски, дубликаты и пустые значения. Дубликатов обнаружено не было, однако были пропуски в `EndDate` и `TotalCharges`. Пропуски в `EndDate` а пропуски в `TotalCharges` мы решили заполнить нулями, поскольку был небольшой процент от выборки в 11 строк. При рассмотрении столбца `EndDate` мы заметили 2 ошибки, а именно, что были данные, где клиент ушёл и у нас не отмечена дата окончания срока действия договора `EndDate`. Другая - Клиент пользуется услугой, но не имеются его общие расходы `TotalCharges`. В итоге было решено исправить итоговую сумму и дату конца договора. Далее мы заметили пропуски из-за несоответствия размерности строк. В итоге мы решили заполнить имеющиеся пропуски наиболее часто повторяющимся значением. Затем мы объединили таблицы в единый датасет и опредилили портреттипичного клиента, который готов расторгнуть договор с компанией по оказываемым услугами рассмотрели взаимозависимости меду признаками на матрице корреляций признаков.
#
# 3. Была разделена выбока на обучающую и тестовую в соотношении 1 к 4. Было рассмотрено 5 моделей и были выявлены лучшие показатели метрик с помощью кросс-валидации. Также была создана константная модель для сравнения с другими моделями. Лучше всего себя показала модель логистической регрессии и Catboost со средним значением качества модели на кросс-валидации 0.59 и ROC AUC: 0.824. Поскольку мы можем протестировать только одну модель, выберем Catboost поскольку он способен обрабатывать сложные нелинейные зависимости и автоматически управлять категориальными признаками.
#
# Были получены следующие результаты по наилучшим параметрам метрики cross_val, не считая константной модели и модели нейронной сети:
#
# * Константная модель: 0.5
# * Логистическая регрессия: 0.8447910385752312
# * Решающее дерево: 0.8557099026427637
# * Случайный лес: 0.8820026067326501
# * Catboost: 0.8913367501507419
# * Модель нейронной сети: Accuracy: 0.7791027825099376
#
# 4. Во время тестирования модели Catboost получено значение метрики ROC AUC 0.92, что больше заявленного по условию задачи (0.85) Благодаря применению метода балансировки класса Upsampling нам удалось повысить метрику качества модели. Также мы проверили модель на дамми-ловушку.
#
# 5. В качестве улучшения работы модели можно предложить проводить более регулярные исследования (панель), а также собирать больший массив опросного исследования и чётко фиксировать дату окончания срока действия договора и общие расходы клиента, чтобы более качественно проводить исследование в новой итерации. Модель также может быть использована для улучшения потока клиентов при учёте слабых сторон компании.
